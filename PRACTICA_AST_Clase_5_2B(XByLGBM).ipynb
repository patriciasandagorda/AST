# %% [markdown]
# <a href="https://colab.research.google.com/github/patriciasandagorda/AST/blob/main/PRACTICA_AST_Clase_5_2B(XByLGBM).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <div class="alert alert-block alert-info">
#     <h1>Análisis de Series Temporales</h1>
#     <h3>Clase 5 - Modelos de Ensambles - Xgboost y LightGBM </h3>
#     <h3>Ejercicio 2B_Sincronico</h3>
#         <p>Docente: Rodrigo Del Rosso, Drago Braian, Sebastian Calcagno<p>
# </div>

# %% [markdown]
# **Modelos Ensambles**
#
# Los modelos de Gradient Boosting, como XGBoost y LightGBM, han demostrado su eficacia en una amplia gama de aplicaciones de aprendizaje automático, desde clasificación hasta regresión. Sin embargo, una de las áreas más desafiantes y emocionantes en las que estos algoritmos han encontrado aplicabilidad es en la predicción de series de tiempo. La adaptación de estos modelos al dominio de series temporales es esencial, ya que las características únicas de este tipo de datos, como la dependencia temporal y la estacionalidad, requieren un enfoque especializado. En esta introducción, exploraremos cómo se aplican y adaptan los modelos de aumento de gradiente para abordar problemas de predicción de series de tiempo.
#
# ¿Qué es el Boosting? Boosting es una técnica conjunta de aprendizaje automático que combina múltiples modelos débiles (weak models) en un único modelo fuerte. En Boosting, cada modelo aprende de los errores del modelo anterior, lo que da como resultado un modelo mejor en general. El objetivo es mejorar la precisión de un modelo reduciendo la varianza y el sesgo en los datos. Boosting es una técnica popular para resolver problemas de clasificación y regresión.
#
# Las principales diferencias de LightGBM frente a XGBoost es su estrategia de crecimiento de árboles en forma de hojas, su técnica exclusiva de agrupación de funciones y su menor consumo de memoria.

# %% [markdown]
# **Objetivo del Ejercicio**:
# Nos centraremos en el problema del consumo de energía, donde, dado un conjunto de datos suficientemente grande del consumo diario de energía de diferentes hogares en una ciudad, tenemos la tarea de predecir con la mayor precisión posible las demandas energéticas futuras.
#
# El dataset contiene el consumo de energía de 5.567 hogares seleccionados al azar en la ciudad de Londres durante el período comprendido entre noviembre de 2011 y febrero de 2014.
#
# Nota: Como queremos predecir el consumo de forma general y no por hogar, debemos agrupar los resultados por fecha y promediar los kilovatios-hora.

# %% [markdown]
# FUENTE DEL DATASET: https://www.kaggle.com/datasets/emmanuelfwerr/london-homes-energy-data

# %% [markdown]
# Carga de Librerías

# %%
import pandas as pd
import requests
from io import BytesIO
import zipfile
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import xgboost as xgb
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import TimeSeriesSplit
from xgboost import plot_importance, plot_tree
color_pal = sns.color_palette()
plt.style.use('tableau-colorblind10')

# %%
# URL del archivo ZIP en GitHub
zip_url = 'https://github.com/braiandrago/AST/blob/main/london_energy.csv.zip?raw=true'

# Descargar el archivo ZIP
response = requests.get(zip_url)
if response.status_code == 200:
    # Leer el contenido del archivo ZIP en un objeto BytesIO
    zip_content = BytesIO(response.content)

    # Descomprimir el archivo ZIP y extraer el archivo CSV
    with zipfile.ZipFile(zip_content, 'r') as zip_file:
        # Supongamos que el archivo CSV dentro del ZIP se llama 'archivo.csv'
        csv_file_name = 'london_energy.csv'
        with zip_file.open(csv_file_name) as csv_file:
            # Leer el archivo CSV en un DataFrame
            df = pd.read_csv(csv_file)

    # Mostrar la información del DataFrame
    df.info()
else:
    print("Error al descargar el archivo ZIP")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3510433 entries, 0 to 3510432
# Data columns (total 3 columns):
#  #   Column  Dtype
# ---  ------  -----
#  0   LCLid   object
#  1   Date    object
#  2   KWH     float64
# dtypes: float64(1), object(2)
# memory usage: 80.3+ MB

# %% [markdown]
# `LCLid` es una cadena única que identifica a cada hogar.
# `Date` variable tiempo.
# `KWH` es el número total de kilovatios-hora gastados en esa fecha y no falta ningún valor.

# %% [markdown]
# # Carga y Procesamiento inicial del dataset

# %%
df.head()
# Out:
#        LCLid        Date     KWH
# 0  MAC000002  2012-10-12   7.098
# 1  MAC000002  2012-10-13  11.087
# 2  MAC000002  2012-10-14  13.223
# 3  MAC000002  2012-10-15  10.257
# 4  MAC000002  2012-10-16   9.769

# %%
print(df.isna().sum())
# Out:
# LCLid    0
# Date     0
# KWH      0
# dtype: int64

# %%
df_avg_consumption = df.groupby("Date")["KWH"].mean()
df_avg_consumption = pd.DataFrame({"date": df_avg_consumption.index.tolist(), "consumption": df_avg_consumption.values.tolist()})
df_avg_consumption["date"] = pd.to_datetime(df_avg_consumption["date"])
print(f"From: {df_avg_consumption['date'].min()}")
print(f"To: {df_avg_consumption['date'].max()}")
# Out:
# From: 2011-11-23 00:00:00
# To: 2014-02-28 00:00:00

# %%
df_avg_consumption.head()
# Out:
#         date  consumption
# 0 2011-11-23     6.952692
# 1 2011-11-24     8.536480
# 2 2011-11-25     9.499781
# 3 2011-11-26    10.267707
# 4 2011-11-27    10.850805

# %%
df_avg_consumption.tail()
# Out:
#           date  consumption
# 824 2014-02-24    10.411403
# 825 2014-02-25    10.294997
# 826 2014-02-26    10.202945
# 827 2014-02-27    10.356350
# 828 2014-02-28     0.417993

# %%
df_avg_consumption.plot(x="date", y="consumption")
# Out:
# <Axes: xlabel='date'>

# %% [markdown]
# Estacionalidad:

# %%
df_avg_consumption.query("date > '2012-01-01' & date < '2013-01-01'").plot(x="date", y="consumption")
# Out:
# <Axes: xlabel='date'>

# %% [markdown]
# **Feature Enginering**

# %% [markdown]
# De manera similar a los ejercicios anteriores....Para entrenar un modelo como XGBoost y LightGB necesitamos crear las funciones nosotros mismos. Actualmente, solo tenemos una característica: la fecha completa. Podemos extraer diferentes características en función de la fecha completa como el día de la semana, el día del año, el mes y otros.

# %%
df_avg_consumption["day_of_week"] = df_avg_consumption["date"].dt.dayofweek
df_avg_consumption["day_of_year"] = df_avg_consumption["date"].dt.dayofyear
df_avg_consumption["month"] = df_avg_consumption["date"].dt.month
df_avg_consumption["quarter"] = df_avg_consumption["date"].dt.quarter
df_avg_consumption["year"] = df_avg_consumption["date"].dt.year

df_avg_consumption.head()
# Out:
#         date  consumption  day_of_week  day_of_year  month  quarter  year
# 0 2011-11-23     6.952692            2          327     11        4  2011
# 1 2011-11-24     8.536480            3          328     11        4  2011
# 2 2011-11-25     9.499781            4          329     11        4  2011
# 3 2011-11-26    10.267707            5          330     11        4  2011
# 4 2011-11-27    10.850805            6          331     11        4  2011

# %% [markdown]
# **Separación de los datos para el modelado:**

# %% [markdown]
# Hasta aqui... date no fue tratada como index. Podemos utilizarla para separar los datos y luego eliminarla.

# %% [markdown]
# Para el conjunto de pruebas usaremos solo los últimos 6 meses. Si el conjunto de entrenamiento fuera más grande, habríamos utilizado todo el último año como conjunto de pruebas.

# %%
training_mask = df_avg_consumption["date"] < "2013-07-28"
training_data = df_avg_consumption.loc[training_mask]
print(training_data.shape)

testing_mask = df_avg_consumption["date"] >= "2013-07-28"
testing_data = df_avg_consumption.loc[testing_mask]
print(testing_data.shape)
# Out:
# (613, 7)
# (216, 7)

# %%
figure, ax = plt.subplots(figsize=(20, 5))
training_data.plot(ax=ax, label="Training", x="date", y="consumption")
testing_data.plot(ax=ax, label="Testing", x="date", y="consumption")
plt.show()

# %%
# Dropping unnecessary `date` column
training_data = training_data.drop(columns=["date"])
testing_dates = testing_data["date"]
testing_data = testing_data.drop(columns=["date"])

X_train = training_data[["day_of_week", "day_of_year", "month", "quarter", "year"]]
y_train = training_data["consumption"]

X_test = testing_data[["day_of_week", "day_of_year", "month", "quarter", "year"]]
y_test = testing_data["consumption"]

# %% [markdown]
# **Entrenamiento del modelo:**

# %% [markdown]
# La optimización de los hiperparámetros se realizará con gridsearch, la cual toma parámetros y algunos valores como configuración y prueba todas las combinaciones posibles.

# %% [markdown]
# Nuevamente, debido a la naturaleza del problema, no podemos simplemente usar una validación cruzada simple de k veces. Scikit learn proporciona el método TimeSeriesSplit que divide los datos de forma incremental de manera respetuosa en términos de continuidad.

# %% [markdown]
# **Para Xgboost:**

# %%
from xgboost import XGBRegressor
import lightgbm as lgb
from sklearn.model_selection import TimeSeriesSplit, GridSearchCV

# XGBoost
cv_split = TimeSeriesSplit(n_splits=4, test_size=100)
model = XGBRegressor()
parameters = {
    "max_depth": [3, 4, 6, 5, 10],
    "learning_rate": [0.01, 0.05, 0.1, 0.2, 0.3],
    "n_estimators": [100, 300, 500, 700, 900, 1000],
    "colsample_bytree": [0.3, 0.5, 0.7]
}


grid_search = GridSearchCV(estimator=model, cv=cv_split, param_grid=parameters)
grid_search.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=TimeSeriesSplit(gap=0, max_train_size=None, n_splits=4, test_size=100),
#              estimator=XGBRegressor(base_score=None, booster=None,
#                                     callbacks=None, colsample_bylevel=None,
#                                     colsample_bynode=None,
#                                     colsample_bytree=None, device=None,
#                                     early_stopping_rounds=None,
#                                     enable_categorical=False, eval_metric=None,
#                                     feature_types=None, gamma=None,
#                                     grow_policy=None, impo...
#                                     max_cat_to_onehot=None, max_delta_step=None,
#                                     max_depth=None, max_leaves=None,
#                                     min_child_weight=None, missing=nan,
#                                     monotone_constraints=None,
#                                     multi_strategy=None, n_estimators=None,
#                                     n_jobs=None, num_parallel_tree=None,
#                                     random_state=None, ...),
#              param_grid={'colsample_bytree': [0.3, 0.5, 0.7],
#                          'learning_rate': [0.01, 0.05, 0.1, 0.2, 0.3],
#                          'max_depth': [3, 4, 6, 5, 10],
#                          'n_estimators': [100, 300, 500, 700, 900, 1000]})

# %% [markdown]
# **Evaluación**

# %%
from sklearn.metrics import mean_absolute_error, mean_absolute_percentage_error,\
  mean_squared_error

def evaluate_model(y_test, prediction):
  print(f"MAE: {mean_absolute_error(y_test, prediction)}")
  print(f"MSE: {mean_squared_error(y_test, prediction)}")
  print(f"MAPE: {mean_absolute_percentage_error(y_test, prediction)}")

def plot_predictions(testing_dates, y_test, prediction):
  df_test = pd.DataFrame({"date": testing_dates, "actual": y_test, "prediction": prediction })
  figure, ax = plt.subplots(figsize=(10, 5))
  df_test.plot(ax=ax, label="Actual", x="date", y="actual")
  df_test.plot(ax=ax, label="Prediction", x="date", y="prediction")
  plt.legend(["Actual", "Prediction"])
  plt.show()

# %%
# Evaluating GridSearch results
prediction = grid_search.predict(X_test)
plot_predictions(testing_dates, y_test, prediction)
evaluate_model(y_test, prediction)
# Out:
# MAE: 0.7330404137119078
# MSE: 1.3902031538115365
# MAPE: 0.1929515940113626

# %% [markdown]
# **Y para LighGBM**

# %%
# LGBM
cv_split = TimeSeriesSplit(n_splits=4, test_size=100)
model = lgb.LGBMRegressor()
parameters = {
    "max_depth": [3, 4, 6, 5, 10],
    "num_leaves": [10, 20, 30, 40, 100, 120],
    "learning_rate": [0.01, 0.05, 0.1, 0.2, 0.3],
    "n_estimators": [50, 100, 300, 500, 700, 900, 1000],
    "colsample_bytree": [0.3, 0.5, 0.7, 1]
}


grid_search = GridSearchCV(estimator=model, cv=cv_split, param_grid=parameters)
grid_search.fit(X_train, y_train)

# %%
# Evaluating GridSearch results
prediction = grid_search.predict(X_test)
plot_predictions(testing_dates, y_test, prediction)
evaluate_model(y_test, prediction)
# Out:
# MAE: 0.7598511155488689
# MSE: 1.4174602236853142
# MAPE: 0.19624274959783336

# %% [markdown]
# **Cómo mejoramos el rendimiento de los modelos?**

# %% [markdown]
# Utilizararemos funciones auxiliares que estén correlacionadas directa o indirectamente con el consumo de energía. Como por ejemplo datos del servicio meteorologico de Londres:

# %% [markdown]
# Fuente del dataset:https://www.kaggle.com/datasets/noahx1/london-weather-2000-2023

# %%
url = 'https://raw.githubusercontent.com/braiandrago/AST/main/london_weather.csv'
df_weather = pd.read_csv(url)
print(df_weather.isna().sum())
df_weather.head()
# Out:
# date                   0
# cloud_cover           19
# sunshine               0
# global_radiation      19
# max_temp               6
# mean_temp             36
# min_temp               2
# precipitation          6
# pressure               4
# snow_depth          1441
# dtype: int64
#        date  cloud_cover  sunshine  global_radiation  max_temp  mean_temp  \
# 0  19790101          2.0       7.0              52.0       2.3       -4.1
# 1  19790102          6.0       1.7              27.0       1.6       -2.6
# 2  19790103          5.0       0.0              13.0       1.3       -2.8
# 3  19790104          8.0       0.0              13.0      -0.3       -2.6
# 4  19790105          6.0       2.0              29.0       5.6       -0.8
#
#    min_temp  precipitation  pressure  snow_depth
# 0      -7.5            0.4  101900.0         9.0
# 1      -7.5            0.0  102530.0         8.0
# 2      -7.2            0.0  102050.0         4.0
# 3      -6.5            0.0  100840.0         2.0
# 4      -1.4            0.0  102250.0         1.0

# %% [markdown]
# Hay varios datos faltantes que es necesario completar. Como tenemos datos meteorológicos en los que cada día depende del día anterior y del siguiente, completaremos esos valores interpolando. Además, convertiremos la columna "fecha" a "fecha y hora" y, luego, fusionaremos los dos datasets para obtener uno mejorado.

# %%
# Parsing dates
df_weather["date"] = pd.to_datetime(df_weather["date"], format="%Y%m%d")

# Filling missing values through interpolation
df_weather = df_weather.ffill()

# Enhancing consumption dataset with weather information
df_avg_consumption = df_avg_consumption.merge(df_weather, how="inner", on="date")
df_avg_consumption.head()
# Out:
#         date  consumption  day_of_week  day_of_year  month  quarter  year  \
# 0 2011-11-23     6.952692            2          327     11        4  2011
# 1 2011-11-24     8.536480            3          328     11        4  2011
# 2 2011-11-25     9.499781            4          329     11        4  2011
# 3 2011-11-26    10.267707            5          330     11        4  2011
# 4 2011-11-27    10.850805            6          331     11        4  2011
#
#    cloud_cover  sunshine  global_radiation  max_temp  mean_temp  min_temp  \
# 0          7.0       2.0              35.0      13.5        6.8       2.6
# 1          3.0       2.0              35.0      12.5        8.6       3.7
# 2          3.0       5.0              52.0      14.0       11.0       9.5
# 3          4.0       0.7              24.0      13.9       10.2       6.3
# 4          3.0       5.9              55.0      13.2       11.8       9.7
#
#    precipitation  pressure  snow_depth
# 0            0.2  102720.0         0.0
# 1            0.2  102710.0         0.0
# 2            0.0  102450.0         0.0
# 3            0.0  102580.0         0.0
# 4            0.0  102130.0         0.0

# %% [markdown]
# **Separación de los datos del nuevo dataset:**

# %%
training_mask = df_avg_consumption["date"] < "2013-07-28"
training_data = df_avg_consumption.loc[training_mask]
print(training_data.shape)

testing_mask = df_avg_consumption["date"] >= "2013-07-28"
testing_data = df_avg_consumption.loc[testing_mask]
print(testing_data.shape)
# Out:
# (613, 16)
# (216, 16)

# %%
# Dropping unnecessary `date` column
training_data = training_data.drop(columns=["date"])
testing_dates = testing_data["date"]
testing_data = testing_data.drop(columns=["date"])

X_train = training_data[["day_of_week", "day_of_year", "month", "quarter", "year",\
                         "cloud_cover", "sunshine", "global_radiation", "max_temp",\
                         "mean_temp", "min_temp", "precipitation", "pressure",\
                         "snow_depth"]]
y_train = training_data["consumption"]


X_test = testing_data[["day_of_week", "day_of_year", "month", "quarter", "year",\
                         "cloud_cover", "sunshine", "global_radiation", "max_temp",\
                         "mean_temp", "min_temp", "precipitation", "pressure",\
                         "snow_depth"]]
y_test = testing_data["consumption"]

# %% [markdown]
# **Entrenamiento**

# %%
from xgboost import XGBRegressor
import lightgbm as lgb
from sklearn.model_selection import TimeSeriesSplit, GridSearchCV

# XGBoost
cv_split = TimeSeriesSplit(n_splits=4, test_size=100)
model = XGBRegressor()
parameters = {
    "max_depth": [3, 4, 6, 5, 10],
    "learning_rate": [0.01, 0.05, 0.1, 0.2, 0.3],
    "n_estimators": [100, 300, 500, 700, 900, 1000],
    "colsample_bytree": [0.3, 0.5, 0.7]
}


grid_search = GridSearchCV(estimator=model, cv=cv_split, param_grid=parameters)
grid_search.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=TimeSeriesSplit(gap=0, max_train_size=None, n_splits=4, test_size=100),
#              estimator=XGBRegressor(base_score=None, booster=None,
#                                     callbacks=None, colsample_bylevel=None,
#                                     colsample_bynode=None,
#                                     colsample_bytree=None, device=None,
#                                     early_stopping_rounds=None,
#                                     enable_categorical=False, eval_metric=None,
#                                     feature_types=None, gamma=None,
#                                     grow_policy=None, impo...
#                                     max_cat_to_onehot=None, max_delta_step=None,
#                                     max_depth=None, max_leaves=None,
#                                     min_child_weight=None, missing=nan,
#                                     monotone_constraints=None,
#                                     multi_strategy=None, n_estimators=None,
#                                     n_jobs=None, num_parallel_tree=None,
#                                     random_state=None, ...),
#              param_grid={'colsample_bytree': [0.3, 0.5, 0.7],
#                          'learning_rate': [0.01, 0.05, 0.1, 0.2, 0.3],
#                          'max_depth': [3, 4, 6, 5, 10],
#                          'n_estimators': [100, 300, 500, 700, 900, 1000]})

# %% [markdown]
# **Evaluación**

# %%
from sklearn.metrics import mean_absolute_error, mean_absolute_percentage_error,\
  mean_squared_error

def evaluate_model(y_test, prediction):
  print(f"MAE: {mean_absolute_error(y_test, prediction)}")
  print(f"MSE: {mean_squared_error(y_test, prediction)}")
  print(f"MAPE: {mean_absolute_percentage_error(y_test, prediction)}")

def plot_predictions(testing_dates, y_test, prediction):
  df_test = pd.DataFrame({"date": testing_dates, "actual": y_test, "prediction": prediction })
  figure, ax = plt.subplots(figsize=(10, 5))
  df_test.plot(ax=ax, label="Actual", x="date", y="actual")
  df_test.plot(ax=ax, label="Prediction", x="date", y="prediction")
  plt.legend(["Actual", "Prediction"])
  plt.show()

# %%
# Evaluating GridSearch results
prediction = grid_search.predict(X_test)
plot_predictions(testing_dates, y_test, prediction)
evaluate_model(y_test, prediction)
# Out:
# MAE: 0.41222399123657294
# MSE: 0.8432288584575132
# MAPE: 0.16246850639888177

# %% [markdown]
# **Para LightGBM**

# %%
# LGBM
cv_split = TimeSeriesSplit(n_splits=4, test_size=100)
model = lgb.LGBMRegressor()
parameters = {
    "max_depth": [3, 4, 6, 5, 10],
    "num_leaves": [10, 20, 30, 40, 100, 120],
    "learning_rate": [0.01, 0.05, 0.1, 0.2, 0.3],
    "n_estimators": [50, 100, 300, 500, 700, 900, 1000],
    "colsample_bytree": [0.3, 0.5, 0.7, 1]
}


grid_search = GridSearchCV(estimator=model, cv=cv_split, param_grid=parameters)
grid_search.fit(X_train, y_train)
# Out:
# Se han truncado las últimas 5000 líneas del flujo de salida.
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000032 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 668
# [LightGBM] [Info] Number of data points in the train set: 313, number of used features: 13
# [LightGBM] [Info] Start training from score 10.225154
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# ...
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf

# %%
# Evaluating GridSearch results
prediction = grid_search.predict(X_test)
plot_predictions(testing_dates, y_test, prediction)
evaluate_model(y_test, prediction)
# Out:
# MAE: 0.476487191053889
# MSE: 0.9170412738351784
# MAPE: 0.16983133657848068

# %% [markdown]
# # Mejoramos el modelo?
# Replicaremos a continuación el entrenamiento con las siguientes modificaciones:
# 1. Generar el dataset "df_avg_consumption" fusionando "df_weather" y el dataset inicial de consumo.
# 2. Agregar 3 lags anuales de la característica "consumption".
# 3. Entrenar el modelo utilizando optimización bayesiana con Optuna.
# 4. Graficar la evolución del error de entrenamiento vs. prueba.
# 5. Graficar Features importances
# 6. Graficar el consumo actual vs. predicho y mostrar las métricas de evaluación con "evaluate_model".

# %% [markdown]
# ## Generación del dataset mejorado
#
# Crear el dataset `df_avg_consumption` fusionando los datos de consumo y meteorológicos, y agregar las 3 características de lag anual para el consumo.

# %%
# URL del archivo ZIP en GitHub
zip_url = 'https://github.com/braiandrago/AST/blob/main/london_energy.csv.zip?raw=true'

# Descargar el archivo ZIP
response = requests.get(zip_url)
if response.status_code == 200:
    # Leer el contenido del archivo ZIP en un objeto BytesIO
    zip_content = BytesIO(response.content)

    # Descomprimir el archivo ZIP y extraer el archivo CSV
    with zipfile.ZipFile(zip_content, 'r') as zip_file:
        # Supongamos que el archivo CSV dentro del ZIP se llama 'archivo.csv'
        csv_file_name = 'london_energy.csv'
        with zip_file.open(csv_file_name) as csv_file:
            # Leer el archivo CSV en un DataFrame
            df = pd.read_csv(csv_file)

    # Mostrar la información del DataFrame
    df.info()
else:
    print("Error al descargar el archivo ZIP")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3510433 entries, 0 to 3510432
# Data columns (total 3 columns):
#  #   Column  Dtype
# ---  ------  -----
#  0   LCLid   object
#  1   Date    object
#  2   KWH     float64
# dtypes: float64(1), object(2)
# memory usage: 80.3+ MB

# %%
df_avg_consumption = df.groupby("Date")["KWH"].mean()
df_avg_consumption = pd.DataFrame({"date": df_avg_consumption.index.tolist(), "consumption": df_avg_consumption.values.tolist()})
df_avg_consumption["date"] = pd.to_datetime(df_avg_consumption["date"])
print(f"From: {df_avg_consumption['date'].min()}")
print(f"To: {df_avg_consumption['date'].max()}")
# Out:
# From: 2011-11-23 00:00:00
# To: 2014-02-28 00:00:00

# %%
df_avg_consumption["day_of_week"] = df_avg_consumption["date"].dt.dayofweek
df_avg_consumption["day_of_year"] = df_avg_consumption["date"].dt.dayofyear
df_avg_consumption["month"] = df_avg_consumption["date"].dt.month
df_avg_consumption["quarter"] = df_avg_consumption["date"].dt.quarter
df_avg_consumption["year"] = df_avg_consumption["date"].dt.year

df_avg_consumption.head()
# Out:
#         date  consumption  day_of_week  day_of_year  month  quarter  year
# 0 2011-11-23     6.952692            2          327     11        4  2011
# 1 2011-11-24     8.536480            3          328     11        4  2011
# 2 2011-11-25     9.499781            4          329     11        4  2011
# 3 2011-11-26    10.267707            5          330     11        4  2011
# 4 2011-11-27    10.850805            6          331     11        4  2011

# %%
url = 'https://raw.githubusercontent.com/braiandrago/AST/main/london_weather.csv'
df_weather = pd.read_csv(url)
print(df_weather.isna().sum())
df_weather.head()
# Out:
# date                   0
# cloud_cover           19
# sunshine               0
# global_radiation      19
# max_temp               6
# mean_temp             36
# min_temp               2
# precipitation          6
# pressure               4
# snow_depth          1441
# dtype: int64
#        date  cloud_cover  sunshine  global_radiation  max_temp  mean_temp  \
# 0  19790101          2.0       7.0              52.0       2.3       -4.1
# 1  19790102          6.0       1.7              27.0       1.6       -2.6
# 2  19790103          5.0       0.0              13.0       1.3       -2.8
# 3  19790104          8.0       0.0              13.0      -0.3       -2.6
# 4  19790105          6.0       2.0              29.0       5.6       -0.8
#
#    min_temp  precipitation  pressure  snow_depth
# 0      -7.5            0.4  101900.0         9.0
# 1      -7.5            0.0  102530.0         8.0
# 2      -7.2            0.0  102050.0         4.0
# 3      -6.5            0.0  100840.0         2.0
# 4      -1.4            0.0  102250.0         1.0

# %%
# Parsing dates
df_weather["date"] = pd.to_datetime(df_weather["date"], format="%Y%m%d")

# Filling missing values through interpolation
df_weather = df_weather.ffill()

# %%
# Merge the dataframes
df_avg_consumption = df_avg_consumption.merge(df_weather, how="inner", on="date")

# Create lag features
df_avg_consumption["consumption_lag_1"] = df_avg_consumption["consumption"].shift(1)
df_avg_consumption["consumption_lag_2"] = df_avg_consumption["consumption"].shift(2)
df_avg_consumption["consumption_lag_3"] = df_avg_consumption["consumption"].shift(3)

# Drop rows with nulls introduced by lags
df_avg_consumption.dropna(inplace=True)

df_avg_consumption.head()
# Out:
#         date  consumption  day_of_week  day_of_year  month  quarter  year  \
# 3 2011-11-26    10.267707            5          330     11        4  2011
# 4 2011-11-27    10.850805            6          331     11        4  2011
# 5 2011-11-28     9.103382            0          332     11        4  2011
# 6 2011-11-29     9.274873            1          333     11        4  2011
# 7 2011-11-30     8.813513            2          334     11        4  2011
#
#    cloud_cover  sunshine  global_radiation  max_temp  mean_temp  min_temp  \
# 3          4.0       0.7              24.0      13.9       10.2       6.3
# 4          3.0       5.9              55.0      13.2       11.8       9.7
# 5          5.0       0.0              15.0      13.9        6.7       0.2
# 6          6.0       0.0              15.0      12.8        8.6       3.3
# 7          4.0       3.7              42.0      11.0        9.2       5.5
#
#    precipitation  pressure  snow_depth  consumption_lag_1  consumption_lag_2  \
# 3            0.0  102580.0         0.0           9.499781           8.536480
# 4            0.0  102130.0         0.0          10.267707           9.499781
# 5            0.0  102270.0         0.0          10.850805          10.267707
# 6            0.4  100960.0         0.0           9.103382          10.850805
# 7            1.2  101920.0         0.0           9.274873           9.103382
#
#    consumption_lag_3
# 3           6.952692
# 4           8.536480
# 5           9.499781
# 6          10.267707
# 7          10.850805

# %% [markdown]
# ## Configuración y optimización bayesiana con optuna
#
# Definir la función objetivo para Optuna que entrene el modelo XGBoost (o LightGBM) con TimeSeriesSplit y devuelva la métrica de evaluación (por ejemplo, MSE). Ejecutar la optimización con Optuna para encontrar los mejores hiperparámetros.

# %%
# %pip install optuna
# Out:
# Collecting optuna
#   Downloading optuna-4.4.0-py3-none-any.whl.metadata (17 kB)
# Collecting alembic>=1.5.0 (from optuna)
#   Downloading alembic-1.16.2-py3-none-any.whl.metadata (7.3 kB)
# Collecting colorlog (from optuna)
#   Downloading colorlog-6.9.0-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from optuna) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from optuna) (24.2)
# Requirement already satisfied: sqlalchemy>=1.4.2 in /usr/local/lib/python3.11/dist-packages (from optuna) (2.0.41)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from optuna) (4.67.1)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.11/dist-packages (from optuna) (6.0.2)
# Requirement already satisfied: Mako in /usr/lib/python3/dist-packages (from alembic>=1.5.0->optuna) (1.1.3)
# Requirement already satisfied: typing-extensions>=4.12 in /usr/local/lib/python3.11/dist-packages (from alembic>=1.5.0->optuna) (4.14.0)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.11/dist-packages (from sqlalchemy>=1.4.2->optuna) (3.2.3)
# Downloading optuna-4.4.0-py3-none-any.whl (395 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 395.9/395.9 kB 8.0 MB/s eta 0:00:00
# Downloading alembic-1.16.2-py3-none-any.whl (242 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 242.7/242.7 kB 18.2 MB/s eta 0:00:00
# Downloading colorlog-6.9.0-py3-none-any.whl (11 kB)
# Installing collected packages: colorlog, alembic, optuna
# Successfully installed alembic-1.16.2 colorlog-6.9.0 optuna-4.4.0

# %%
import optuna
from xgboost import XGBRegressor
from sklearn.model_selection import TimeSeriesSplit
from sklearn.metrics import mean_squared_error
import numpy as np

# Separate features and target
X = df_avg_consumption.drop(columns=["date", "consumption"])
y = df_avg_consumption["consumption"]

# Define the split point
split_date = "2013-07-28"
training_mask = df_avg_consumption["date"] < split_date

X_train = X.loc[training_mask]
y_train = y.loc[training_mask]

X_test = X.loc[~training_mask]
y_test = y.loc[~training_mask]


def objective(trial, X_train, y_train):
    param = {
        'objective': 'reg:squarederror',
        'eval_metric': 'rmse',
        'n_estimators': trial.suggest_int('n_estimators', 100, 1000),
        'learning_rate': trial.suggest_float('learning_rate', 0.01, 0.3),
        'max_depth': trial.suggest_int('max_depth', 3, 10),
        'colsample_bytree': trial.suggest_float('colsample_bytree', 0.3, 1.0),
        'subsample': trial.suggest_float('subsample', 0.3, 1.0),
        'gamma': trial.suggest_float('gamma', 0, 0.5),
        'min_child_weight': trial.suggest_int('min_child_weight', 1, 10),
        'random_state': 42 # Add random state for reproducibility
    }

    tscv = TimeSeriesSplit(n_splits=4, test_size=100)
    rmse_scores = []
    eval_results = {} # Dictionary to store evaluation results for each fold

    for fold, (train_index, val_index) in enumerate(tscv.split(X_train)):
        X_train_fold, X_val_fold = X_train.iloc[train_index], X_train.iloc[val_index]
        y_train_fold, y_val_fold = y_train.iloc[train_index], y_train.iloc[val_index]

        model = xgb.XGBRegressor(**param)
        model.fit(X_train_fold, y_train_fold,
                  eval_set=[(X_train_fold, y_train_fold), (X_val_fold, y_val_fold)],
                  verbose=False) # Removed duplicate eval_metric

        predictions = model.predict(X_val_fold)
        mse = mean_squared_error(y_val_fold, predictions)
        rmse = np.sqrt(mse)
        rmse_scores.append(rmse)

        # Store evaluation results for the current fold
        eval_results[f'fold_{fold}'] = model.evals_result()


    # Store evaluation results in trial's user attributes
    trial.set_user_attr('eval_results', eval_results)


    return np.mean(rmse_scores)

study = optuna.create_study(direction='minimize')
study.optimize(lambda trial: objective(trial, X_train, y_train), n_trials=50)

print("Best hyperparameters: ", study.best_params)
# Out:
# [I 2025-06-26 00:12:26,625] A new study created in memory with name: no-name-41ef7bae-8578-4623-8c42-822e391dda15
# [I 2025-06-26 00:12:27,672] Trial 0 finished with value: 0.3477080776175008 and parameters: {'n_estimators': 540, 'learning_rate': 0.15725709101446136, 'max_depth': 9, 'colsample_bytree': 0.4474771354761483, 'subsample': 0.9815008841197868, 'gamma': 0.16187105385796602, 'min_child_weight': 4}. Best is trial 0 with value: 0.3477080776175008.
# [I 2025-06-26 00:12:28,162] Trial 1 finished with value: 0.38522043678800677 and parameters: {'n_estimators': 175, 'learning_rate': 0.2369140367448432, 'max_depth': 4, 'colsample_bytree': 0.538809857504103, 'subsample': 0.4257684794156423, 'gamma': 0.268963413663218, 'min_child_weight': 5}. Best is trial 0 with value: 0.3477080776175008.
# [I 2025-06-26 00:12:29,631] Trial 2 finished with value: 0.3318407479686136 and parameters: {'n_estimators': 511, 'learning_rate': 0.08414223660281249, 'max_depth': 5, 'colsample_bytree': 0.8364209435546874, 'subsample': 0.9307407038356872, 'gamma': 0.2237611472860897, 'min_child_weight': 2}. Best is trial 2 with value: 0.3318407479686136.
# [I 2025-06-26 00:12:30,025] Trial 3 finished with value: 0.3795686063867948 and parameters: {'n_estimators': 118, 'learning_rate': 0.2781605299363688, 'max_depth': 7, 'colsample_bytree': 0.99736215671553, 'subsample': 0.9897665367409791, 'gamma': 0.2034718967576385, 'min_child_weight': 1}. Best is trial 2 with value: 0.3318407479686136.
# [I 2025-06-26 00:12:30,894] Trial 4 finished with value: 0.36282154424401003 and parameters: {'n_estimators': 469, 'learning_rate': 0.2310863831675014, 'max_depth': 3, 'colsample_bytree': 0.3126029666658761, 'subsample': 0.5632888504069014, 'gamma': 0.41955181433200284, 'min_child_weight': 10}. Best is trial 2 with value: 0.3318407479686136.
# [I 2025-06-26 00:12:31,544] Trial 5 finished with value: 0.34570671469342684 and parameters: {'n_estimators': 126, 'learning_rate': 0.1338172430309111, 'max_depth': 3, 'colsample_bytree': 0.40149199204632335, 'subsample': 0.5257307373672686, 'gamma': 0.21491336064709965, 'min_child_weight': 4}. Best is trial 2 with value: 0.3318407479686136.
# [I 2025-06-26 00:12:32,802] Trial 6 finished with value: 0.3315784920651578 and parameters: {'n_estimators': 525, 'learning_rate': 0.03447257433237413, 'max_depth': 4, 'colsample_bytree': 0.694168563258289, 'subsample': 0.7006958318649298, 'gamma': 0.3319750216486775, 'min_child_weight': 9}. Best is trial 6 with value: 0.3315784920651578.
# [I 2025-06-26 00:12:34,184] Trial 7 finished with value: 0.37318211658696515 and parameters: {'n_estimators': 495, 'learning_rate': 0.14132633874458045, 'max_depth': 9, 'colsample_bytree': 0.9018772499826484, 'subsample': 0.392540426321005, 'gamma': 0.1431775887550108, 'min_child_weight': 5}. Best is trial 6 with value: 0.3315784920651578.
# [I 2025-06-26 00:12:35,362] Trial 8 finished with value: 0.35715056588884636 and parameters: {'n_estimators': 545, 'learning_rate': 0.18096755662899378, 'max_depth': 10, 'colsample_bytree': 0.3839160875540348, 'subsample': 0.46416755300915574, 'gamma': 0.3422217878380768, 'min_child_weight': 3}. Best is trial 6 with value: 0.3315784920651578.
# [I 2025-06-26 00:12:35,926] Trial 9 finished with value: 0.38829046983697024 and parameters: {'n_estimators': 207, 'learning_rate': 0.19924122728319407, 'max_depth': 4, 'colsample_bytree': 0.9873356424308326, 'subsample': 0.33199448986613084, 'gamma': 0.3235256949697735, 'min_child_weight': 9}. Best is trial 6 with value: 0.3315784920651578.
# [I 2025-06-26 00:12:42,174] Trial 10 finished with value: 0.3322520325720955 and parameters: {'n_estimators': 936, 'learning_rate': 0.011688113778227066, 'max_depth': 6, 'colsample_bytree': 0.7028761169692067, 'subsample': 0.7651251838517537, 'gamma': 0.032214981538982834, 'min_child_weight': 7}. Best is trial 6 with value: 0.3315784920651578.
# [I 2025-06-26 00:12:43,776] Trial 11 finished with value: 0.3341916402933416 and parameters: {'n_estimators': 773, 'learning_rate': 0.04816329566913529, 'max_depth': 6, 'colsample_bytree': 0.7534504798335317, 'subsample': 0.7713723339148923, 'gamma': 0.45485028302246266, 'min_child_weight': 8}. Best is trial 6 with value: 0.3315784920651578.
# [I 2025-06-26 00:12:44,949] Trial 12 finished with value: 0.33114106392480736 and parameters: {'n_estimators': 342, 'learning_rate': 0.0810210329163828, 'max_depth': 5, 'colsample_bytree': 0.8122340744380432, 'subsample': 0.8191791748206866, 'gamma': 0.3557943722735848, 'min_child_weight': 2}. Best is trial 12 with value: 0.33114106392480736.
# [I 2025-06-26 00:12:45,701] Trial 13 finished with value: 0.34754658786452747 and parameters: {'n_estimators': 330, 'learning_rate': 0.0884611175925033, 'max_depth': 5, 'colsample_bytree': 0.5948691604960838, 'subsample': 0.7561448979571979, 'gamma': 0.3776363603780783, 'min_child_weight': 7}. Best is trial 12 with value: 0.33114106392480736.
# [I 2025-06-26 00:12:48,015] Trial 14 finished with value: 0.3214968510991951 and parameters: {'n_estimators': 707, 'learning_rate': 0.015646386346807956, 'max_depth': 7, 'colsample_bytree': 0.7961392244023155, 'subsample': 0.6543189203987426, 'gamma': 0.49499435444018747, 'min_child_weight': 7}. Best is trial 14 with value: 0.3214968510991951.
# [I 2025-06-26 00:12:51,891] Trial 15 finished with value: 0.32768425814673985 and parameters: {'n_estimators': 730, 'learning_rate': 0.09266162960418896, 'max_depth': 7, 'colsample_bytree': 0.8288670494691874, 'subsample': 0.8834519570857757, 'gamma': 0.49497608983920666, 'min_child_weight': 6}. Best is trial 14 with value: 0.3214968510991951.
# [I 2025-06-26 00:12:53,732] Trial 16 finished with value: 0.33679297973941763 and parameters: {'n_estimators': 725, 'learning_rate': 0.11110529469191777, 'max_depth': 8, 'colsample_bytree': 0.886492210584787, 'subsample': 0.8521824598893831, 'gamma': 0.49647847670171963, 'min_child_weight': 6}. Best is trial 14 with value: 0.3214968510991951.
# [I 2025-06-26 00:12:55,440] Trial 17 finished with value: 0.33260296316174687 and parameters: {'n_estimators': 710, 'learning_rate': 0.052140384869633856, 'max_depth': 7, 'colsample_bytree': 0.6287937350034839, 'subsample': 0.65561482815003, 'gamma': 0.4972399417325576, 'min_child_weight': 7}. Best is trial 14 with value: 0.3214968510991951.
# [I 2025-06-26 00:12:57,963] Trial 18 finished with value: 0.3270687524341076 and parameters: {'n_estimators': 853, 'learning_rate': 0.01606602859314966, 'max_depth': 8, 'colsample_bytree': 0.7791881272053771, 'subsample': 0.5823781629852346, 'gamma': 0.42347100627364515, 'min_child_weight': 6}. Best is trial 14 with value: 0.3214968510991951.
# [I 2025-06-26 00:13:00,832] Trial 19 finished with value: 0.3230130560486511 and parameters: {'n_estimators': 980, 'learning_rate': 0.010971949987335756, 'max_depth': 8, 'colsample_bytree': 0.7613677909611262, 'subsample': 0.5746509790225772, 'gamma': 0.4151404989667818, 'min_child_weight': 8}. Best is trial 14 with value: 0.3214968510991951.
# [I 2025-06-26 00:13:04,911] Trial 20 finished with value: 0.33423057290631847 and parameters: {'n_estimators': 993, 'learning_rate': 0.04460376699020524, 'max_depth': 8, 'colsample_bytree': 0.5396791848683382, 'subsample': 0.624068943055711, 'gamma': 0.4134618026550253, 'min_child_weight': 10}. Best is trial 14 with value: 0.3214968510991951.
# [I 2025-06-26 00:13:07,494] Trial 21 finished with value: 0.32151957096820083 and parameters: {'n_estimators': 869, 'learning_rate': 0.010785674143205868, 'max_depth': 8, 'colsample_bytree': 0.7548407574369655, 'subsample': 0.5746192934090875, 'gamma': 0.4308926425160795, 'min_child_weight': 8}. Best is trial 14 with value: 0.3214968510991951.
# [I 2025-06-26 00:13:09,908] Trial 22 finished with value: 0.32287150722056024 and parameters: {'n_estimators': 884, 'learning_rate': 0.015417634532437136, 'max_depth': 9, 'colsample_bytree': 0.7231059401339842, 'subsample': 0.5107170277293664, 'gamma': 0.4497041754544869, 'min_child_weight': 8}. Best is trial 14 with value: 0.3214968510991951.
# [I 2025-06-26 00:13:11,871] Trial 23 finished with value: 0.33829641311443637 and parameters: {'n_estimators': 843, 'learning_rate': 0.0658135851134874, 'max_depth': 10, 'colsample_bytree': 0.6972261218714038, 'subsample': 0.4857734549551475, 'gamma': 0.45904843985767163, 'min_child_weight': 8}. Best is trial 14 with value: 0.3214968510991951.
# [I 2025-06-26 00:13:13,841] Trial 24 finished with value: 0.3278821343091002 and parameters: {'n_estimators': 672, 'learning_rate': 0.0336052033833317, 'max_depth': 9, 'colsample_bytree': 0.9159642693804588, 'subsample': 0.6857813349865596, 'gamma': 0.2978036118253727, 'min_child_weight': 9}. Best is trial 14 with value: 0.3214968510991951.
# [I 2025-06-26 00:13:17,391] Trial 25 finished with value: 0.3610962958596793 and parameters: {'n_estimators': 630, 'learning_rate': 0.11432605876998457, 'max_depth': 9, 'colsample_bytree': 0.6333659082695181, 'subsample': 0.5035876831124324, 'gamma': 0.3828605410322722, 'min_child_weight': 8}. Best is trial 14 with value: 0.3214968510991951.
# [I 2025-06-26 00:13:19,466] Trial 26 finished with value: 0.33910161890082824 and parameters: {'n_estimators': 865, 'learning_rate': 0.06337304676629368, 'max_depth': 7, 'colsample_bytree': 0.7270831213535629, 'subsample': 0.3737194642404101, 'gamma': 0.4529939408682437, 'min_child_weight': 7}. Best is trial 14 with value: 0.3214968510991951.
# [I 2025-06-26 00:13:22,318] Trial 27 finished with value: 0.3270484630525732 and parameters: {'n_estimators': 806, 'learning_rate': 0.02887809927652995, 'max_depth': 10, 'colsample_bytree': 0.8557062010054063, 'subsample': 0.6184477913683396, 'gamma': 0.042749384511338695, 'min_child_weight': 9}. Best is trial 14 with value: 0.3214968510991951.
# [I 2025-06-26 00:13:23,889] Trial 28 finished with value: 0.3834784882153592 and parameters: {'n_estimators': 630, 'learning_rate': 0.29969023839607395, 'max_depth': 8, 'colsample_bytree': 0.5515833762878413, 'subsample': 0.7100810979684892, 'gamma': 0.3888351790574355, 'min_child_weight': 10}. Best is trial 14 with value: 0.3214968510991951.
# [I 2025-06-26 00:13:25,617] Trial 29 finished with value: 0.3428715789900396 and parameters: {'n_estimators': 896, 'learning_rate': 0.0651764251492442, 'max_depth': 9, 'colsample_bytree': 0.6625350968285703, 'subsample': 0.45492563849135975, 'gamma': 0.46973647132466273, 'min_child_weight': 7}. Best is trial 14 with value: 0.3214968510991951.
# [I 2025-06-26 00:13:29,966] Trial 30 finished with value: 0.3489669760825976 and parameters: {'n_estimators': 924, 'learning_rate': 0.16793826483227714, 'max_depth': 6, 'colsample_bytree': 0.9471482280449083, 'subsample': 0.5298345275073363, 'gamma': 0.29576341203298484, 'min_child_weight': 5}. Best is trial 14 with value: 0.3214968510991951.
# [I 2025-06-26 00:13:32,790] Trial 31 finished with value: 0.3255206208772919 and parameters: {'n_estimators': 999, 'learning_rate': 0.011833259402521272, 'max_depth': 8, 'colsample_bytree': 0.774743200575923, 'subsample': 0.5706968662317666, 'gamma': 0.4150287322270949, 'min_child_weight': 8}. Best is trial 14 with value: 0.3214968510991951.
# [I 2025-06-26 00:13:34,901] Trial 32 finished with value: 0.3251004470440047 and parameters: {'n_estimators': 796, 'learning_rate': 0.029478520318601986, 'max_depth': 9, 'colsample_bytree': 0.7913659829811476, 'subsample': 0.6067021709905329, 'gamma': 0.44401499774385705, 'min_child_weight': 8}. Best is trial 14 with value: 0.3214968510991951.
# [I 2025-06-26 00:13:37,641] Trial 33 finished with value: 0.32206467823226076 and parameters: {'n_estimators': 944, 'learning_rate': 0.01165413930576088, 'max_depth': 8, 'colsample_bytree': 0.7547697101558364, 'subsample': 0.6661159599497584, 'gamma': 0.4715659883166001, 'min_child_weight': 9}. Best is trial 14 with value: 0.3214968510991951.
# [I 2025-06-26 00:13:41,451] Trial 34 finished with value: 0.32809376333114176 and parameters: {'n_estimators': 938, 'learning_rate': 0.04649148857121893, 'max_depth': 7, 'colsample_bytree': 0.8551132253772771, 'subsample': 0.6692717855914238, 'gamma': 0.47080092518196404, 'min_child_weight': 9}. Best is trial 14 with value: 0.3214968510991951.
# [I 2025-06-26 00:13:44,246] Trial 35 finished with value: 0.33615662462980006 and parameters: {'n_estimators': 776, 'learning_rate': 0.02845386783203736, 'max_depth': 8, 'colsample_bytree': 0.732060704602885, 'subsample': 0.7273669749308428, 'gamma': 0.15404682651288173, 'min_child_weight': 10}. Best is trial 14 with value: 0.3214968510991951.
# [I 2025-06-26 00:13:46,450] Trial 36 finished with value: 0.3393224154562489 and parameters: {'n_estimators': 888, 'learning_rate': 0.06962477679255281, 'max_depth': 7, 'colsample_bytree': 0.6710446080391443, 'subsample': 0.6405402819976797, 'gamma': 0.08414583773391437, 'min_child_weight': 9}. Best is trial 14 with value: 0.3214968510991951.
# [I 2025-06-26 00:13:47,850] Trial 37 finished with value: 0.34158901906301187 and parameters: {'n_estimators': 623, 'learning_rate': 0.11206538157804771, 'max_depth': 9, 'colsample_bytree': 0.6052641951576561, 'subsample': 0.5426346947739491, 'gamma': 0.36576546615342054, 'min_child_weight': 6}. Best is trial 14 with value: 0.3214968510991951.
# [I 2025-06-26 00:13:49,767] Trial 38 finished with value: 0.3789365643090009 and parameters: {'n_estimators': 832, 'learning_rate': 0.2309063889836146, 'max_depth': 10, 'colsample_bytree': 0.49363037483001654, 'subsample': 0.4192323091360888, 'gamma': 0.25704970016225653, 'min_child_weight': 4}. Best is trial 14 with value: 0.3214968510991951.
# [I 2025-06-26 00:13:52,246] Trial 39 finished with value: 0.32760489204447385 and parameters: {'n_estimators': 931, 'learning_rate': 0.02406200960847478, 'max_depth': 6, 'colsample_bytree': 0.8056195036831965, 'subsample': 0.6038462112403865, 'gamma': 0.4282709457938609, 'min_child_weight': 7}. Best is trial 14 with value: 0.3214968510991951.
# [I 2025-06-26 00:13:55,432] Trial 40 finished with value: 0.3251651013988525 and parameters: {'n_estimators': 429, 'learning_rate': 0.04054548375506199, 'max_depth': 9, 'colsample_bytree': 0.7319294723638905, 'subsample': 0.5158698694173053, 'gamma': 0.4791308647370961, 'min_child_weight': 8}. Best is trial 14 with value: 0.3214968510991951.
# [I 2025-06-26 00:13:57,948] Trial 41 finished with value: 0.32632250373626986 and parameters: {'n_estimators': 951, 'learning_rate': 0.01828610552324487, 'max_depth': 8, 'colsample_bytree': 0.74307218456627, 'subsample': 0.5684691223294348, 'gamma': 0.4021951521434547, 'min_child_weight': 8}. Best is trial 14 with value: 0.3214968510991951.
# [I 2025-06-26 00:14:00,519] Trial 42 finished with value: 0.32447709143521863 and parameters: {'n_estimators': 888, 'learning_rate': 0.013252802729144534, 'max_depth': 8, 'colsample_bytree': 0.7661711015396414, 'subsample': 0.47317599285636924, 'gamma': 0.4416125879901081, 'min_child_weight': 9}. Best is trial 14 with value: 0.3214968510991951.
# [I 2025-06-26 00:14:02,940] Trial 43 finished with value: 0.3407593860241226 and parameters: {'n_estimators': 979, 'learning_rate': 0.05414692562687971, 'max_depth': 7, 'colsample_bytree': 0.8693990964492357, 'subsample': 0.6652256210131818, 'gamma': 0.18047239365698572, 'min_child_weight': 8}. Best is trial 14 with value: 0.3214968510991951.
# [I 2025-06-26 00:14:04,986] Trial 44 finished with value: 0.3291565458503193 and parameters: {'n_estimators': 754, 'learning_rate': 0.03552519113537253, 'max_depth': 8, 'colsample_bytree': 0.6929709579787972, 'subsample': 0.5490239026756434, 'gamma': 0.436361622863049, 'min_child_weight': 7}. Best is trial 14 with value: 0.3214968510991951.
# [I 2025-06-26 00:14:09,530] Trial 45 finished with value: 0.32756194184777987 and parameters: {'n_estimators': 819, 'learning_rate': 0.010011068051255272, 'max_depth': 7, 'colsample_bytree': 0.8193988266527683, 'subsample': 0.7302445942554315, 'gamma': 0.40240389689797745, 'min_child_weight': 10}. Best is trial 14 with value: 0.3214968510991951.
# [I 2025-06-26 00:14:11,151] Trial 46 finished with value: 0.3391869159734031 and parameters: {'n_estimators': 678, 'learning_rate': 0.07482176284072013, 'max_depth': 9, 'colsample_bytree': 0.703425979339528, 'subsample': 0.43322792320297854, 'gamma': 0.47637523792489284, 'min_child_weight': 9}. Best is trial 14 with value: 0.3214968510991951.
# [I 2025-06-26 00:14:12,972] Trial 47 finished with value: 0.3168114498067063 and parameters: {'n_estimators': 587, 'learning_rate': 0.05460034948523391, 'max_depth': 8, 'colsample_bytree': 0.8344207185385424, 'subsample': 0.5910978999495172, 'gamma': 0.35996788515599143, 'min_child_weight': 1}. Best is trial 47 with value: 0.3168114498067063.
# [I 2025-06-26 00:14:14,424] Trial 48 finished with value: 0.3341742755611753 and parameters: {'n_estimators': 596, 'learning_rate': 0.05512201626334816, 'max_depth': 6, 'colsample_bytree': 0.9233972433670222, 'subsample': 0.7908127354023895, 'gamma': 0.34755303382252184, 'min_child_weight': 1}. Best is trial 47 with value: 0.3168114498067063.
# [I 2025-06-26 00:14:15,857] Trial 49 finished with value: 0.3320693531942189 and parameters: {'n_estimators': 470, 'learning_rate': 0.09932738200393527, 'max_depth': 10, 'colsample_bytree': 0.8340911951665527, 'subsample': 0.5981664134238255, 'gamma': 0.22962909610759313, 'min_child_weight': 3}. Best is trial 47 with value: 0.3168114498067063.
# Best hyperparameters:  {'n_estimators': 587, 'learning_rate': 0.05460034948523391, 'max_depth': 8, 'colsample_bytree': 0.8344207185385424, 'subsample': 0.5910978999495172, 'gamma': 0.35996788515599143, 'min_child_weight': 1}

# %% [markdown]
# ## Entrenamiento del modelo final
#
# Entrenar el modelo XGBoost (o LightGBM) con los hiperparámetros óptimos encontrados por Optuna utilizando el dataset completo de entrenamiento.

# %%
# Instantiate the XGBoost Regressor with the best hyperparameters
best_params = study.best_params
model = xgb.XGBRegressor(**best_params)

# Fit the model to the complete training data
model.fit(X_train, y_train)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=0.3411933575354841, device=None,
#              early_stopping_rounds=None, enable_categorical=False,
#              eval_metric=None, feature_types=None, gamma=0.4773830163917096,
#              grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=0.02760955879521959,
#              max_bin=None, max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=6, max_leaves=None,
#              min_child_weight=1, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=890, n_jobs=None,
#              num_parallel_tree=None, random_state=None, ...)

# %% [markdown]
# ## Evaluación y visualización de predicciones
#
# Utilizar el modelo entrenado para predecir el consumo en el conjunto de prueba y visualizar las predicciones junto con los valores reales. Mostrar las métricas de evaluación (MAE, MSE, MAPE).

# %%
import matplotlib.pyplot as plt

# Plot the training and validation history for the best trial
best_trial = study.best_trial
results = best_trial.user_attrs['eval_results']

# Assuming you want to plot for the last fold's evaluation results
# You can modify this to plot for a different fold if needed
last_fold_results = results[f'fold_{len(results)-1}']

train_error = last_fold_results['validation_0']['rmse']
val_error = last_fold_results['validation_1']['rmse']

epoch = range(1, len(train_error) + 1)

plt.figure(figsize=(10, 6))
plt.plot(epoch, train_error, label='Train')
plt.plot(epoch, val_error, label='Validation')
plt.xlabel('Number of Boosting Rounds')
plt.ylabel('Root Mean Squared Error (RMSE)')
plt.title('Training and Validation History for Best Optuna Trial (Last Fold)')
plt.legend()
plt.show()

# %%
# Plot feature importances
plt.figure(figsize=(10, 6))
plot_importance(model, ax=plt.gca())
plt.title('Feature Importances (XGBoost)')
plt.show()

# %%
# Generate predictions on the test set
prediction = model.predict(X_test)

# Plot the predictions against the actual values
plot_predictions(testing_dates, y_test, prediction)

# Display the evaluation metrics
evaluate_model(y_test, prediction)
# Out:
# MAE: 0.27581799281462177
# MSE: 0.5986504915026558
# MAPE: 0.13886096684891475
