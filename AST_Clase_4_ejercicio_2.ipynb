# %% [markdown]
# <a href="https://colab.research.google.com/github/patriciasandagorda/AST/blob/main/AST_Clase_4_ejercicio_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <div class="alert alert-block alert-info">
#     <h1>Análisis de Series Temporales</h1>
#     <h3>Clase 4 - Modelo VAR</h3>
#     <h3>Ejercicio 2</h3>
#         <p>Docente: Rodrigo Del Rosso<p>
#         <p>Asistentes: Sebastián Calcagno y Braian Drago<p>
# </div>

# %% [markdown]
# Modelo VAR
#
# Un modelo VAR es una generalizacion del modelo autorregresivo univariado para pronosticar un vector de series de tiempo. Comprende una ecuacion por variable en el sistema. El lado derecho de cada ecuacion incluye una constante y retrasos de todas las variables.
#
# Si las series son estacionarias, se pronostican ajustando directamente un VAR a los datos (conocido como VAR en niveles). Si las series no son estacionarias, tomamos las diferencias de los datos para hacerlas estacionarias y luego ajustamos un modelo VAR (conocido como “VAR en diferencias”). En ambos casos, los modelos se estiman ecuación a ecuación utilizando el principio de mínimos cuadrados.
#
# Los MODELOS VAR son útiles en varios contextos:
#
# 1. Pronosticar una colección de variables relacionadas donde no se requiere interpretación explícita;
# 2. Probar si una variable es útil para pronosticar otra (la base de las pruebas de causalidad de Granger);
# 3. Análisis de respuesta de impulso, donde se analiza la respuesta de una variable a un cambio repentino pero temporal en otra variable;
#
# Se dice que dos o más series están cointegradas si las mismas se mueven conjuntamente a lo largo del tiempo y las diferencias entre ellas son estables (es decir estacionarias), aun cuando cada serie en particular contenga una tendencia estocástica y sea por lo tanto no estacionaria.
#
# Entonces, la cointegración refleja la presencia de un equilibrio a largo plazo hacia el cual converge el sistema a lo largo del tiempo.

# %% [markdown]
# **Objetivo del Ejercicio**: Para el desarrollo del MODELO VAR, incorporamos la serie de precios del **Petróleo** junto con dos productos hidrocarburos más (todo expresado en USD/tn). A través del conocimiento del negocio, entendemos que ambos hidrocarburos (Benceno y Estireno) se producen como derivados del petróleo, entonces se analiza a continuación su relación y la respuestas a impulsos.

# %% [markdown]
# Analizamos conjuntamente los precios del petróleo, el benceno y el estireno mediante un modelo VAR, aprovechando que existe una relación económica entre estos productos. Primero evaluamos la estacionariedad y la posible cointegración para decidir si corresponde trabajar en niveles, en diferencias o utilizar un VECM. Luego aplicamos causalidad de Granger para analizar si el pasado de una variable ayuda a pronosticar a las demás, estimamos el VAR y usamos funciones impulso-respuesta y descomposición de varianza para estudiar cómo se transmiten los shocks dentro del sistema. Finalmente realizamos pronósticos y los comparamos con los valores observados.

# %% [markdown]
# ![PROCESO.PNG](data:image/png;base64,...)

# %% [markdown]
# **Montaje de Drive personal para acceder a archivos/ datasets**
#
# 1.   Elemento de lista
# 2.   Elemento de lista

# %% [markdown]
# Carga de Librerías

# %%
# !pip install pmdarima
# !pip install numpy==1.26.4 pandas==2.2.2 statsmodels==0.14.4 pmdarima==2.0.4  # Primero
# !pip install scipy==1.13.1  # Segundo
# Out:
# Collecting numpy==1.26.4
#   Downloading numpy-1.26.4-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.0/61.0 kB 1.8 MB/s eta 0:00:00
# Requirement already satisfied: pandas==2.2.2 in /usr/local/lib/python3.12/dist-packages (2.2.2)
# Collecting statsmodels==0.14.4
#   Downloading statsmodels-0.14.4-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (9.2 kB)
# Collecting pmdarima==2.0.4
#   Downloading pmdarima-2.0.4-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_28_x86_64.whl.metadata (7.8 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas==2.2.2) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas==2.2.2) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas==2.2.2) (2025.2)
# Requirement already satisfied: scipy!=1.9.2,>=1.8 in /usr/local/lib/python3.12/dist-packages (from statsmodels==0.14.4) (1.16.1)
# Requirement already satisfied: patsy>=0.5.6 in /usr/local/lib/python3.12/dist-packages (from statsmodels==0.14.4) (1.0.1)
# Requirement already satisfied: packaging>=21.3 in /usr/local/lib/python3.12/dist-packages (from statsmodels==0.14.4) (25.0)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.12/dist-packages (from pmdarima==2.0.4) (1.5.1)
# Requirement already satisfied: Cython!=0.29.18,!=0.29.31,>=0.29 in /usr/local/lib/python3.12/dist-packages (from pmdarima==2.0.4) (3.0.12)
# Requirement already satisfied: scikit-learn>=0.22 in /usr/local/lib/python3.12/dist-packages (from pmdarima==2.0.4) (1.6.1)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.12/dist-packages (from pmdarima==2.0.4) (2.5.0)
# Requirement already satisfied: setuptools!=50.0.0,>=38.6.0 in /usr/local/lib/python3.12/dist-packages (from pmdarima==2.0.4) (75.2.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas==2.2.2) (1.17.0)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=0.22->pmdarima==2.0.4) (3.6.0)
# Downloading numpy-1.26.4-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.0/18.0 MB 56.8 MB/s eta 0:00:00
# Downloading statsmodels-0.14.4-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (10.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.7/10.7 MB 82.5 MB/s eta 0:00:00
# Downloading pmdarima-2.0.4-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_28_x86_64.whl (2.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 57.1 MB/s eta 0:00:00
# Installing collected packages: numpy, statsmodels, pmdarima
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.0.2
#     Uninstalling numpy-2.0.2:
#       Successfully uninstalled numpy-2.0.2
#   Attempting uninstall: statsmodels
#     Found existing installation: statsmodels 0.14.5
#     Uninstalling statsmodels-0.14.5:
#       Successfully uninstalled statsmodels-0.14.5
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# opencv-python 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# opencv-contrib-python 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# opencv-python-headless 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# thinc 8.3.6 requires numpy<3.0.0,>=2.0.0, but you have numpy 1.26.4 which is incompatible.
# Successfully installed numpy-1.26.4 pmdarima-2.0.4 statsmodels-0.14.4
# Collecting scipy==1.13.1
#   Downloading scipy-1.13.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (60 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.6/60.6 kB 2.0 MB/s eta 0:00:00
# Requirement already satisfied: numpy<2.3,>=1.22.4 in /usr/local/lib/python3.12/dist-packages (from scipy==1.13.1) (1.26.4)
# Downloading scipy-1.13.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (38.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 38.2/38.2 MB 16.3 MB/s eta 0:00:00
# ^C

# %%
import scipy
import statsmodels
print(scipy.__version__)
print(statsmodels.__version__)
# Out:
# 1.16.1
# 0.14.4

# %%
import pandas as pd
import numpy as np
from datetime import datetime
import matplotlib.pyplot as plt
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from statsmodels.tsa.api import VAR  #
from statsmodels.tsa.statespace.varmax import VARMAX
from scipy.stats import pearsonr
import pmdarima as pm
import statsmodels.api as sm
from statsmodels.tsa.stattools import grangercausalitytests, adfuller    #
from sklearn.metrics import mean_absolute_error, mean_squared_error
from scipy.stats import jarque_bera, shapiro, boxcox, probplot
from statsmodels.graphics.tsaplots import plot_pacf, plot_acf
from statsmodels.stats.diagnostic import acorr_ljungbox, acorr_breusch_godfrey
from sklearn.metrics import mean_squared_error
import math
from statistics import mean
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# /tmp/ipython-input-4004988429.py in <cell line: 0>()
#       7 from statsmodels.tsa.statespace.varmax import VARMAX
#       8 from scipy.stats import pearsonr
# ----> 9 import pmdarima as pm
#      10 import statsmodels.api as sm
#      11 from statsmodels.tsa.stattools import grangercausalitytests, adfuller    #
#
# /usr/local/lib/python3.12/dist-packages/pmdarima/__init__.py in <module>
#      50
#      51     # Stuff we want at top-level
# ---> 52     from .arima import auto_arima, ARIMA, AutoARIMA, StepwiseContext, decompose
#      53     from .utils import acf, autocorr_plot, c, pacf, plot_acf, plot_pacf, \
#      54         tsdisplay
#
# /usr/local/lib/python3.12/dist-packages/pmdarima/arima/__init__.py in <module>
#       4
#       5 from .approx import *
# ----> 6 from .arima import *
#       7 from .auto import *
#       8 from .utils import *
#
# /usr/local/lib/python3.12/dist-packages/pmdarima/arima/arima.py in <module>
#      14 from scipy.stats import gaussian_kde, norm
#      15 from sklearn.utils.validation import check_array
# ---> 16 from statsmodels import api as sm
#      17
#      18 from . import _validation as val
#
# /usr/local/lib/python3.12/dist-packages/statsmodels/api.py in <module>
#      74
#      75
# ---> 76 from . import datasets, distributions, iolib, regression, robust, tools
#      77 from .__init__ import test
#      78 from statsmodels._version import (
#
# /usr/local/lib/python3.12/dist-packages/statsmodels/distributions/__init__.py in <module>
#       5 from .edgeworth import ExpandedNormal
#       6
# ----> 7 from .discrete import (
#       8     genpoisson_p, zipoisson, zigenpoisson, zinegbin,
#       9     )
#
# /usr/local/lib/python3.12/dist-packages/statsmodels/distributions/discrete.py in <module>
#       3 from scipy.stats import rv_discrete, poisson, nbinom
#       4 from scipy.special import gammaln
# ----> 5 from scipy._lib._util import _lazywhere
#       6
#       7 from statsmodels.base.model import GenericLikelihoodModel
#
# ImportError: cannot import name '_lazywhere' from 'scipy._lib._util' (/usr/local/lib/python3.12/dist-packages/scipy/_lib/_util.py)
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %% [markdown]
# Carga de datos

# %%
url='https://raw.githubusercontent.com/sebcalcagno/AnalisisSeriesTemporales/main/Estireno_base.csv'
Estireno = pd.read_csv(url,  parse_dates=['FECHA'], index_col='FECHA')
Estireno.head()
# Out:
#             STYRENE FOB ARA US$-TON
# FECHA
# 2006-01-01               1143.41579
# 2006-02-01               1106.04782
# 2006-03-01               1015.87968
# 2006-04-01               1023.92647
# 2006-05-01               1127.32221

# %%
url='https://raw.githubusercontent.com/sebcalcagno/AnalisisSeriesTemporales/main/Benceno_base.csv'
Benceno = pd.read_csv(url,  parse_dates=['FECHA'], index_col='FECHA')
Benceno.head()
# Out:
#             BENCENO SPOT USGC US$-TON
# FECHA
# 2006-01-01                  818.03410
# 2006-02-01                  841.84945
# 2006-03-01                  807.74850
# 2006-04-01                  865.11165
# 2006-05-01                  928.05115

# %%
url='https://raw.githubusercontent.com/braiandrago/AST/main/petroleo_wti.csv'
Petroleo = pd.read_csv(url,  parse_dates=['FECHA'], index_col='FECHA')
Petroleo.head()
# Out:
# /tmp/ipython-input-2306320119.py:2: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   Petroleo = pd.read_csv(url,  parse_dates=['FECHA'], index_col='FECHA')
#             CRUDE_OIL_WTI
# FECHA
# 2006-01-01       486.7393
# 2006-02-01       457.9109
# 2006-03-01       467.3470
# 2006-04-01       517.7967
# 2006-05-01       527.0842

# %%
precios = Estireno.merge(Benceno,on='FECHA').merge(Petroleo,on='FECHA')
print(precios)
# Out:
#             STYRENE FOB ARA US$-TON  BENCENO SPOT USGC US$-TON  CRUDE_OIL_WTI
# FECHA
# 2006-01-01               1143.41579                  818.03410       486.7393
# 2006-02-01               1106.04782                  841.84945       457.9109
# 2006-03-01               1015.87968                  807.74850       467.3470
# 2006-04-01               1023.92647                  865.11165       517.7967
# 2006-05-01               1127.32221                  928.05115       527.0842
# ...                             ...                        ...            ...
# 2015-08-01               1087.74964                  684.71000       318.5241
# 2015-09-01                846.56640                  609.96000       337.9164
# 2015-10-01                846.34594                  635.64410       343.4146
# 2015-11-01                854.50296                  687.37110       315.3292
# 2015-12-01                845.02318                  642.70050       276.3217
#
# [120 rows x 3 columns]

# %%
precios  = precios .asfreq(pd.infer_freq(precios .index))

# %%
precios.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 120 entries, 2006-01-01 to 2015-12-01
# Freq: MS
# Data columns (total 3 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   STYRENE FOB ARA US$-TON    120 non-null    float64
#  1   BENCENO SPOT USGC US$-TON  120 non-null    float64
#  2   CRUDE_OIL_WTI              120 non-null    float64
# dtypes: float64(3)
# memory usage: 3.8 KB

# %%
plt.figure(figsize=(12,6))
STYRENE, = plt.plot(precios ['STYRENE FOB ARA US$-TON'])
BENCENO, = plt.plot(precios ['BENCENO SPOT USGC US$-TON'], color='green')
CRUDE, = plt.plot(precios ['CRUDE_OIL_WTI'], color='red')

for year in range(2006, 2016):
    plt.axvline(datetime(year,1,1), linestyle='--', color='k', alpha=0.5)

plt.legend(['STYRENE', 'BENCENO','CRUDE'], fontsize=16);

# %% [markdown]
# **Estacionariedad?**

# %% [markdown]
# Para una serie temporal estacionaria, el ACF caerá a cero con relativa rapidez, mientras que el ACF de datos no estacionarios disminuye lentamente. (https://otexts.com/fpp2/stationarity.html)

# %%
acf_plot = plot_acf(precios ['STYRENE FOB ARA US$-TON'], lags=24,  color= 'blue')
acf_plot.set_size_inches(12,3)

# %%
acf_plot = plot_acf(precios ['BENCENO SPOT USGC US$-TON'], lags=24,  color= 'green')
acf_plot.set_size_inches(12,3)

# %%
acf_plot = plot_acf(precios ['CRUDE_OIL_WTI'], lags=24,  color= 'red')
acf_plot.set_size_inches(12,3)

# %%
print(pm.arima.ndiffs(precios['STYRENE FOB ARA US$-TON']))
# Out:
# 0
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(

# %%
print(pm.arima.ndiffs(precios['BENCENO SPOT USGC US$-TON']))
# Out:
# 0
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(

# %%
print(pm.arima.ndiffs(precios['CRUDE_OIL_WTI']))
# Out:
# 0
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(

# %% [markdown]
# Ho es la hipotesis nula. La serie tiene una raiz unitaria, la serie NO es estacionaria.

# %%
# Test de Dickey-Fuller
def test_stationarity(timeseries):
    print('Results of Dickey-Fuller Test:')
    dftest = adfuller(timeseries, autolag='AIC')
    dfoutput = pd.Series(dftest[0:4], index=['Test Statistic','p-value','#Lags Used','Number of Observations Used'])
    for key,value in dftest[4].items():
        dfoutput['Critical Value (%s)'%key] = value
    print(dfoutput)
test_stationarity(precios['STYRENE FOB ARA US$-TON'])
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                  -2.850392
# p-value                          0.051428
# #Lags Used                       2.000000
# Number of Observations Used    117.000000
# Critical Value (1%)             -3.487517
# Critical Value (5%)             -2.886578
# Critical Value (10%)            -2.580124
# dtype: float64

# %% [markdown]
# el valor critico al 10% (-2.5801) se podrias rechazar en un nivel del 10%.

# %%
test_stationarity(precios['BENCENO SPOT USGC US$-TON'])
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                  -2.686257
# p-value                          0.076447
# #Lags Used                       2.000000
# Number of Observations Used    117.000000
# Critical Value (1%)             -3.487517
# Critical Value (5%)             -2.886578
# Critical Value (10%)            -2.580124
# dtype: float64

# %%
test_stationarity(precios['CRUDE_OIL_WTI'])
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                  -2.988323
# p-value                          0.035999
# #Lags Used                       2.000000
# Number of Observations Used    117.000000
# Critical Value (1%)             -3.487517
# Critical Value (5%)             -2.886578
# Critical Value (10%)            -2.580124
# dtype: float64

# %% [markdown]
# Cointegración?  Es decir, si tienen una rel de equilibrio a largo plazo.

# %% [markdown]
# https://www.statsmodels.org/stable/generated/statsmodels.tsa.stattools.coint.html

# %%
from statsmodels.tsa.stattools import coint

# %% [markdown]
# La hipótesis nula es NO HAY COINTEGRACION. Si p-value > 0.05, NO rechazamos H0.

# %%
coint(precios['BENCENO SPOT USGC US$-TON'],precios ['CRUDE_OIL_WTI'])
# Out:
# (-2.6367300311097583,
#  0.22315428572217233,
#  array([-3.99084033, -3.38795719, -3.08028241]))

# %% [markdown]
# p-value of 0.2231 -> NO rechazamos la hipótesis nula.
#
# Decimos que: No hay evidencia de cointegración entre Benceno y Crudo.

# %%
coint(precios['BENCENO SPOT USGC US$-TON'],precios ['STYRENE FOB ARA US$-TON'])
# Out:
# (-4.936871716835145,
#  0.0002147216727379106,
#  array([-3.99084033, -3.38795719, -3.08028241]))

# %%
coint(precios['STYRENE FOB ARA US$-TON'],precios ['CRUDE_OIL_WTI'])
# Out:
# (-3.319498422571883,
#  0.0521115292920656,
#  array([-3.99084033, -3.38795719, -3.08028241]))

# %% [markdown]
# **Causalidad de Granger**
#
# El Test de Granger permite entender y analizar si los valores pasados de una variable *x* podrían ayudar a la predicción de los valores futuros de una variable *y*.
#
# H0:"Serie x" NO CAUSA en el sentido de Granger a "serie y" (p-value > 0.05 No Rechazo H0)
# H1:"Serie x" CAUSA en el sentido de Granger a "serie y"
#
# A continuación, se analiza las relaciones de los precios de los hidrocarburos.

# %%
print('Petroleo causes Estireno?\n')
print('------------------')
granger_1 = grangercausalitytests(precios[['STYRENE FOB ARA US$-TON', 'CRUDE_OIL_WTI']], 3)

print('------------------')
print('------------------')

print('\Estireno causes Petroleo?\n')
print('------------------')
granger_2 = grangercausalitytests(precios[['CRUDE_OIL_WTI', 'STYRENE FOB ARA US$-TON']], 3)
# Out:
# Petroleo causes Estireno?
#
# ------------------
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=10.8963 , p=0.0013  , df_denom=116, df_num=1
# ssr based chi2 test:   chi2=11.1781 , p=0.0008  , df=1
# likelihood ratio test: chi2=10.6838 , p=0.0011  , df=1
# parameter F test:         F=10.8963 , p=0.0013  , df_denom=116, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=14.0715 , p=0.0000  , df_denom=113, df_num=2
# ssr based chi2 test:   chi2=29.3883 , p=0.0000  , df=2
# likelihood ratio test: chi2=26.2416 , p=0.0000  , df=2
# parameter F test:         F=14.0715 , p=0.0000  , df_denom=113, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=10.0132 , p=0.0000  , df_denom=110, df_num=3
# ssr based chi2 test:   chi2=31.9511 , p=0.0000  , df=3
# likelihood ratio test: chi2=28.2490 , p=0.0000  , df=3
# parameter F test:         F=10.0132 , p=0.0000  , df_denom=110, df_num=3
# ------------------
# ------------------
# \Estireno causes Petroleo?
#
# ------------------
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=1.1008  , p=0.2963  , df_denom=116, df_num=1
# ssr based chi2 test:   chi2=1.1293  , p=0.2879  , df=1
# likelihood ratio test: chi2=1.1239  , p=0.2891  , df=1
# parameter F test:         F=1.1008  , p=0.2963  , df_denom=116, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.5478  , p=0.5798  , df_denom=113, df_num=2
# ssr based chi2 test:   chi2=1.1440  , p=0.5644  , df=2
# likelihood ratio test: chi2=1.1385  , p=0.5659  , df=2
# parameter F test:         F=0.5478  , p=0.5798  , df_denom=113, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=0.2552  , p=0.8575  , df_denom=110, df_num=3
# ssr based chi2 test:   chi2=0.8145  , p=0.8460  , df=3
# likelihood ratio test: chi2=0.8116  , p=0.8467  , df=3
# parameter F test:         F=0.2552  , p=0.8575  , df_denom=110, df_num=3
# <>:8: SyntaxWarning: invalid escape sequence '\E'
# <>:8: SyntaxWarning: invalid escape sequence '\E'
# /tmp/ipython-input-1056616358.py:8: SyntaxWarning: invalid escape sequence '\E'
#   print('\Estireno causes Petroleo?\n')

# %% [markdown]
# En base al estadístico, podría decirse que valores pasados de Petroleo podrían ayudar a predecir los valores futuros de Estireno. El p-value arrojado es de 0.0000 . por lo que se rechaza la no causalidad, afirmando que existe causalidad. Por otro lado, el precio del estireno no ayuda a predecir el petroleo. No hay evidencia de causalidad de Granger en ese sentido.

# %%
print('Benceno causes Estireno?\n')
print('------------------')
granger_1 = grangercausalitytests(precios[['STYRENE FOB ARA US$-TON', 'BENCENO SPOT USGC US$-TON']], 3)

print('\Estireno causes Benceno?\n')
print('------------------')
granger_2 = grangercausalitytests(precios[['BENCENO SPOT USGC US$-TON', 'STYRENE FOB ARA US$-TON']], 3)
# Out:
# Benceno causes Estireno?
#
# ------------------
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=25.9829 , p=0.0000  , df_denom=116, df_num=1
# ssr based chi2 test:   chi2=26.6548 , p=0.0000  , df=1
# likelihood ratio test: chi2=24.0518 , p=0.0000  , df=1
# parameter F test:         F=25.9829 , p=0.0000  , df_denom=116, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=11.1633 , p=0.0000  , df_denom=113, df_num=2
# ssr based chi2 test:   chi2=23.3146 , p=0.0000  , df=2
# likelihood ratio test: chi2=21.2759 , p=0.0000  , df=2
# parameter F test:         F=11.1633 , p=0.0000  , df_denom=113, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=6.9219  , p=0.0003  , df_denom=110, df_num=3
# ssr based chi2 test:   chi2=22.0872 , p=0.0001  , df=3
# likelihood ratio test: chi2=20.2325 , p=0.0002  , df=3
# parameter F test:         F=6.9219  , p=0.0003  , df_denom=110, df_num=3
# \Estireno causes Benceno?
#
# ------------------
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=9.9086  , p=0.0021  , df_denom=116, df_num=1
# ssr based chi2 test:   chi2=10.1649 , p=0.0014  , df=1
# likelihood ratio test: chi2=9.7540  , p=0.0018  , df=1
# parameter F test:         F=9.9086  , p=0.0021  , df_denom=116, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=1.0530  , p=0.3523  , df_denom=113, df_num=2
# ssr based chi2 test:   chi2=2.1992  , p=0.3330  , df=2
# likelihood ratio test: chi2=2.1790  , p=0.3364  , df=2
# parameter F test:         F=1.0530  , p=0.3523  , df_denom=113, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=1.0182  , p=0.3875  , df_denom=110, df_num=3
# ssr based chi2 test:   chi2=3.2490  , p=0.3548  , df=3
# likelihood ratio test: chi2=3.2047  , p=0.3611  , df=3
# parameter F test:         F=1.0182  , p=0.3875  , df_denom=110, df_num=3
# <>:5: SyntaxWarning: invalid escape sequence '\E'
# <>:5: SyntaxWarning: invalid escape sequence '\E'
# /tmp/ipython-input-2436614815.py:5: SyntaxWarning: invalid escape sequence '\E'
#   print('\Estireno causes Benceno?\n')

# %% [markdown]
# En base al estadístico, podría decirse que valores pasados de Benceno podrían ayudar a predecir los valores futuros de Estireno. El p-value arrojado es de 0.0000 ** por lo que se rechaza la no causalidad, afirmando que existe causalidad.

# %% [markdown]
# **Modelo VAR**

# %%
train_df=precios[:-12]
test_df=precios[-12:]

# %%
model = VAR(train_df.diff()[1:])

# %%
sorted_order=model.select_order(maxlags=25)
print(sorted_order.summary())
# Out:
#  VAR Order Selection (* highlights the minimums)
# ==================================================
#        AIC         BIC         FPE         HQIC
# --------------------------------------------------
# 0        25.53       25.62   1.227e+11       25.57
# 1        24.95      25.31*   6.880e+10       25.10
# 2        24.74       25.36  5.553e+10*       24.99
# 3        24.82       25.70   6.052e+10       25.18
# 4        24.84       25.98   6.160e+10       25.30
# 5        24.86       26.27   6.353e+10       25.43
# 6        24.96       26.64   7.116e+10       25.63
# 7        25.09       27.02   8.179e+10       25.86
# 8        25.17       27.37   9.077e+10       26.06
# 9        25.12       27.59   8.881e+10       26.11
# 10       25.25       27.98   1.038e+11       26.34
# 11       25.19       28.18   1.022e+11       26.39
# 12       25.22       28.48   1.110e+11       26.53
# 13       25.20       28.73   1.158e+11       26.62
# 14       25.06       28.85   1.088e+11       26.58
# 15       25.17       29.22   1.326e+11       26.80
# 16       25.15       29.46   1.451e+11       26.88
# 17       25.00       29.58   1.433e+11       26.84
# 18       24.99       29.83   1.666e+11       26.93
# 19       24.73       29.83   1.561e+11       26.78
# 20       24.73       30.10   1.993e+11       26.88
# 21       24.10       29.74   1.447e+11       26.36
# 22       24.08       29.98   2.092e+11       26.45
# 23       23.70       29.86   2.368e+11       26.17
# 24       22.55       28.97   1.513e+11       25.13
# 25      21.44*       28.13   1.432e+11      24.12*
# --------------------------------------------------

# %%
results = model.fit(maxlags=25,
                    ic='aic',
                    verbose=1
                   )
# Out:
# <statsmodels.tsa.vector_ar.var_model.LagOrderResults object. Selected orders are: AIC -> 25, BIC -> 1, FPE -> 2, HQIC ->  25>
# Using 25 based on aic criterion

# %%
print(results.summary()._resid_info())
# Out:
# Correlation matrix of residuals
#                              STYRENE FOB ARA US$-TON  BENCENO SPOT USGC US$-TON  CRUDE_OIL_WTI
# STYRENE FOB ARA US$-TON                     1.000000                   0.645756      -0.298420
# BENCENO SPOT USGC US$-TON                   0.645756                   1.000000      -0.566146
# CRUDE_OIL_WTI                              -0.298420                  -0.566146       1.000000

# %%
normality = results.test_normality()
print(normality.summary())
# Out:
# normality (skew and kurtosis) test. H_0: data generated by normally-distributed process. Conclusion: fail to reject H_0 at 5% significance level.
# ========================================
# Test statistic Critical value p-value df
# ----------------------------------------
#          2.594          12.59   0.858  6
# ----------------------------------------

# %% [markdown]
# No podemos rechazar normalidad en los residuos

# %%
for quant in precios.columns:
    plot_acf(results.resid[quant],title='Autocorrelation function - residual {}'.format(quant))

# %% [markdown]
# Los gráficos de los residuos muestran que no hay autocorrelaciones en cada residuo, como sería de esperar si el modelo utilizado se ajustara bien a los datos.

# %% [markdown]
# **Impuso Respuesta**
#
# Para comprender mejor cómo el cambio de una cantidad en el pasado influye en otra cantidad en el presente, podemos utilizar la respuesta impulsiva. La idea es que comencemos con un cambio de unidad para una sola cantidad en n
#   rezagos y estudiar cómo se propaga este shock en otra variable.
#
# Consideraremos la función impulso-respuesta para aquellas variables que están relacionadas causalmente con Granger.

# %% [markdown]
# A través de la relación impulso - respuesta, calculando el efecto sobre Estireno a partir de un impulso unitario en Petroleo, se observa:

# %%
# Impulse response function for the model we trained
irf = results.irf(periods=10)
irf.plot(figsize=(24,8)) #Impulse response function plot
plt.show()

# %%
fevd = results.fevd(10)

# %%
fevd.plot(figsize=(24,8)) #Impulse response function plot
plt.show()

# %%
fevd.summary()
# Out:
# FEVD for STYRENE FOB ARA US$-TON
#      STYRENE FOB ARA US$-TON  BENCENO SPOT USGC US$-TON  CRUDE_OIL_WTI
# 0                   1.000000                   0.000000       0.000000
# 1                   0.785158                   0.104809       0.110033
# 2                   0.572275                   0.187599       0.240125
# 3                   0.546112                   0.183043       0.270844
# 4                   0.542849                   0.183247       0.273904
# 5                   0.544345                   0.182614       0.273041
# 6                   0.543524                   0.184163       0.272313
# 7                   0.542133                   0.185050       0.272816
# 8                   0.541767                   0.184904       0.273330
# 9                   0.541697                   0.184922       0.273381
#
# FEVD for BENCENO SPOT USGC US$-TON
#      STYRENE FOB ARA US$-TON  BENCENO SPOT USGC US$-TON  CRUDE_OIL_WTI
# 0                   0.591749                   0.408251       0.000000
# 1                   0.510877                   0.436929       0.052195
# 2                   0.424867                   0.372372       0.202760
# 3                   0.416233                   0.361640       0.222127
# 4                   0.417849                   0.360536       0.221615
# 5                   0.419099                   0.360413       0.220488
# 6                   0.417817                   0.361061       0.221121
# 7                   0.417227                   0.360566       0.222207
# 8                   0.417126                   0.360471       0.222403
# 9                   0.417151                   0.360457       0.222393
#
# FEVD for CRUDE_OIL_WTI
#      STYRENE FOB ARA US$-TON  BENCENO SPOT USGC US$-TON  CRUDE_OIL_WTI
# 0                   0.134792                   0.011791       0.853417
# 1                   0.117230                   0.026127       0.856643
# 2                   0.113021                   0.091546       0.795433
# 3                   0.110740                   0.101152       0.788108
# 4                   0.109337                   0.100450       0.790213
# 5                   0.109018                   0.100118       0.790864
# 6                   0.109242                   0.100517       0.790241
# 7                   0.109273                   0.100954       0.789773
# 8                   0.109223                   0.101040       0.789737
# 9                   0.109205                   0.101028       0.789766

# %% [markdown]
# Interpretacion: Observando por ejemplo el período 5, Dado un impulso en la variable Estireno, el 54% esta explicado por ella misma,  el 18% Por el Benceno y un 27% Por el petróleo.

# %% [markdown]
# **Forecast**

# %%
# Get the lag order
lag_order = results.k_ar
print(lag_order)

# Input data for forecasting
forecast_input = train_df.values[-lag_order:]
forecast_input
# Out:
# 2
# array([[1336.20806, 1030.3839 ,  563.1197 ],
#        [1034.39832,  754.4667 ,  440.5247 ]])

# %%
# Forecast
n_forecast = 12
fc = results.forecast(y=forecast_input, steps=n_forecast)
df_forecast = pd.DataFrame(fc, index=precios.index[-n_forecast:], columns=precios.columns + '_1d')
df_forecast
# Out:
#             STYRENE FOB ARA US$-TON_1d  BENCENO SPOT USGC US$-TON_1d  \
# FECHA
# 2015-01-01                  436.786590                    302.057728
# 2015-02-01                  177.830453                    181.619327
# 2015-03-01                  147.543685                    160.514918
# 2015-04-01                  152.569548                    136.702524
# 2015-05-01                  101.982741                     71.558707
# 2015-06-01                   43.303329                     26.540001
# 2015-07-01                   15.208288                     14.772900
# 2015-08-01                   12.854929                     16.348997
# 2015-09-01                   13.442330                     12.560071
# 2015-10-01                    8.058444                      4.634211
# 2015-11-01                    1.226232                     -0.554370
# 2015-12-01                   -1.983076                     -1.466674
#
#             CRUDE_OIL_WTI_1d
# FECHA
# 2015-01-01        222.138237
# 2015-02-01        141.291800
# 2015-03-01         85.693717
# 2015-04-01         61.902019
# 2015-05-01         41.060361
# 2015-06-01         25.283601
# 2015-07-01         13.275692
# 2015-08-01          7.141590
# 2015-09-01          4.476374
# 2015-10-01          2.753640
# 2015-11-01          0.926610
# 2015-12-01         -0.499476

# %% [markdown]
# Invertimos las transformaciones: queremos revertir las transformaciones que se han aplicado previamente a un conjunto de datos con el fin de obtener pronósticos

# %%
def invert_transformation(df_train, df_forecast, second_diff=False):
    """Revert back the differencing to get the forecast to original scale."""
    df_fc = df_forecast.copy()
    columns = train_df.columns
    for col in columns:
        # Roll back 2nd Diff
        if second_diff:
            df_fc[str(col)+'_1d'] = (train_df[col].iloc[-1]-train_df[col].iloc[-2]) + df_fc[str(col)+'_2d'].cumsum()
        # Roll back 1st Diff
        df_fc[str(col)+'_forecast'] = train_df[col].iloc[-1] + df_fc[str(col)+'_1d'].cumsum()
    return df_fc

# %%
df_results = invert_transformation(train_df, df_forecast, second_diff=False)
df_results.loc[:, ['STYRENE FOB ARA US$-TON_forecast', 'BENCENO SPOT USGC US$-TON_forecast', 'CRUDE_OIL_WTI_forecast']]
# Out:
#             STYRENE FOB ARA US$-TON_forecast  \
# FECHA
# 2015-01-01                       1471.184910
# 2015-02-01                       1649.015363
# 2015-03-01                       1796.559048
# 2015-04-01                       1949.128596
# 2015-05-01                       2051.111337
# 2015-06-01                       2094.414665
# 2015-07-01                       2109.622954
# 2015-08-01                       2122.477883
# 2015-09-01                       2135.920213
# 2015-10-01                       2143.978657
# 2015-11-01                       2145.204889
# 2015-12-01                       2143.221814
#
#             BENCENO SPOT USGC US$-TON_forecast  CRUDE_OIL_WTI_forecast
# FECHA
# 2015-01-01                         1056.524428              662.662937
# 2015-02-01                         1238.143755              803.954738
# 2015-03-01                         1398.658673              889.648454
# 2015-04-01                         1535.361197              951.550473
# 2015-05-01                         1606.919904              992.610834
# 2015-06-01                         1633.459905             1017.894435
# 2015-07-01                         1648.232805             1031.170128
# 2015-08-01                         1664.581802             1038.311718
# 2015-09-01                         1677.141873             1042.788092
# 2015-10-01                         1681.776084             1045.541732
# 2015-11-01                         1681.221714             1046.468342
# 2015-12-01                         1679.755040             1045.968866

# %% [markdown]
# Las previsiones vuelven a la escala original. Trazamos los pronósticos con los datos reales de los datos de prueba.

# %%
fig, axes = plt.subplots(nrows=3, ncols=1, dpi=100, figsize=(8, 12))

for i, (col,ax) in enumerate(zip(precios.columns, axes.flatten())):
    df_results[col+'_forecast'].plot(legend=True, ax=ax).autoscale(axis='x',tight=True)
    test_df[col][-n_forecast:].plot(legend=True, ax=ax);
    ax.set_title(col)
    ax.xaxis.set_ticks_position('none')
    ax.yaxis.set_ticks_position('none')
    #ax.tick_params(labelsize=6, direction= 'out')
    ax.legend(fontsize="8",loc='upper center')

plt.tight_layout()
plt.show();

# %% [markdown]
# **Evaluate the Forecasts**

# %%
rmse_estireno=math.sqrt(mean_squared_error(df_results['STYRENE FOB ARA US$-TON_forecast'],test_df['STYRENE FOB ARA US$-TON']))
print('Mean value of Estireno is : {}. Root Mean Squared Error is :{}'.format(mean(test_df['STYRENE FOB ARA US$-TON']),rmse_estireno))

rmse_benceno=math.sqrt(mean_squared_error(df_results['BENCENO SPOT USGC US$-TON_forecast'],test_df['BENCENO SPOT USGC US$-TON']))
print('Mean value of Benceno is : {}. Root Mean Squared Error is :{}'.format(mean(test_df['BENCENO SPOT USGC US$-TON']),rmse_benceno))

rmse_petroleo=math.sqrt(mean_squared_error(df_results['CRUDE_OIL_WTI_forecast'],test_df['CRUDE_OIL_WTI']))
print('Mean value of Petroleo is : {}. Root Mean Squared Error is :{}'.format(mean(test_df['CRUDE_OIL_WTI']),rmse_petroleo))
# Out:
# Mean value of Estireno is : 1033.84717. Root Mean Squared Error is :987.0204615638307
# Mean value of Benceno is : 706.4074333333333. Root Mean Squared Error is :856.5176028915965
# Mean value of Petroleo is : 361.7543166666667. Root Mean Squared Error is :616.4600295462549
