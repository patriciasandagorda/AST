# %% [markdown]
# <a href="https://colab.research.google.com/github/patriciasandagorda/AST/blob/main/AST_Clase_4_ejercicio_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <div class="alert alert-block alert-info">
#     <h1>Análisis de Series Temporales</h1>
#     <h3>Clase 4</h3>
#     <h3>Ejercicio 1</h3>
#         <p>Docente: Rodrigo Del Rosso<p>
#         <p>Asistentes: Sebastián Calcagno y Braian Drago <p>
# </div>

# %% [markdown]
# **Índices de precios internacionales de productos básicos en US$ por tonelada**

# %% [markdown]
# ![datosarg.PNG](data:image/png;base64,...)

# %% [markdown]
# Modelo VAR

# %% [markdown]
# En un modelo VAR se trabajan con multiples series temporales.
# Un modelo VAR utiliza ecuaciones simultáneas para describir cómo cada variable depende de sus valores anteriores y de los valores anteriores de todas las demás variables en el modelo. Esto permite capturar las interacciones y relaciones dinámicas entre las variables.

# %% [markdown]
# Aplicamos un modelo VAR a los precios del maíz, el trigo y la cebada para estudiar cómo se relacionan y cómo los valores pasados de cada producto pueden ayudar a explicar a los demás. Como las series en niveles no son estacionarias, trabajamos con sus primeras diferencias, seleccionamos la cantidad de rezagos, estimamos el modelo y evaluamos sus pronósticos y residuos. También utilizamos causalidad de Granger y funciones impulso-respuesta para analizar cómo un cambio inesperado en uno de los precios se transmite hacia los otros.

# %% [markdown]
# Carga de librerías y funciones necesarias:

# %%
# !pip install pmdarima
# !pip install numpy==1.26.4 pandas==2.2.2 statsmodels==0.14.4 pmdarima==2.0.4  #Primero
# !pip install scipy==1.13.1  #Segundo
# Out:
# Collecting numpy==1.26.4
#   Downloading numpy-1.26.4-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.0/61.0 kB 4.8 MB/s eta 0:00:00
# Requirement already satisfied: pandas==2.2.2 in /usr/local/lib/python3.12/dist-packages (2.2.2)
# Collecting statsmodels==0.14.4
#   Downloading statsmodels-0.14.4-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (9.2 kB)
# Collecting pmdarima==2.0.4
#   Downloading pmdarima-2.0.4-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_28_x86_64.whl.metadata (7.8 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas==2.2.2) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas==2.2.2) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas==2.2.2) (2025.2)
# Requirement already satisfied: scipy!=1.9.2,>=1.8 in /usr/local/lib/python3.12/dist-packages (from statsmodels==0.14.4) (1.16.1)
# Requirement already satisfied: patsy>=0.5.6 in /usr/local/lib/python3.12/dist-packages (from statsmodels==0.14.4) (1.0.1)
# Requirement already satisfied: packaging>=21.3 in /usr/local/lib/python3.12/dist-packages (from statsmodels==0.14.4) (25.0)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.12/dist-packages (from pmdarima==2.0.4) (1.5.1)
# Requirement already satisfied: Cython!=0.29.18,!=0.29.31,>=0.29 in /usr/local/lib/python3.12/dist-packages (from pmdarima==2.0.4) (3.0.12)
# Requirement already satisfied: scikit-learn>=0.22 in /usr/local/lib/python3.12/dist-packages (from pmdarima==2.0.4) (1.6.1)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.12/dist-packages (from pmdarima==2.0.4) (2.5.0)
# Requirement already satisfied: setuptools!=50.0.0,>=38.6.0 in /usr/local/lib/python3.12/dist-packages (from pmdarima==2.0.4) (75.2.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas==2.2.2) (1.17.0)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=0.22->pmdarima==2.0.4) (3.6.0)
# Downloading numpy-1.26.4-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.0/18.0 MB 46.9 MB/s eta 0:00:00
# Downloading statsmodels-0.14.4-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (10.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.7/10.7 MB 67.6 MB/s eta 0:00:00
# Downloading pmdarima-2.0.4-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_28_x86_64.whl (2.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 48.1 MB/s eta 0:00:00
# Installing collected packages: numpy, statsmodels, pmdarima
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.0.2
#     Uninstalling numpy-2.0.2:
#       Successfully uninstalled numpy-2.0.2
#   Attempting uninstall: statsmodels
#     Found existing installation: statsmodels 0.14.5
#     Uninstalling statsmodels-0.14.5:
#       Successfully uninstalled statsmodels-0.14.5
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# opencv-python 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# opencv-contrib-python 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# opencv-python-headless 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# thinc 8.3.6 requires numpy<3.0.0,>=2.0.0, but you have numpy 1.26.4 which is incompatible.
# Successfully installed numpy-1.26.4 pmdarima-2.0.4 statsmodels-0.14.4
# Collecting scipy==1.13.1
#   Downloading scipy-1.13.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (60 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.6/60.6 kB 4.4 MB/s eta 0:00:00
# Requirement already satisfied: numpy<2.3,>=1.22.4 in /usr/local/lib/python3.12/dist-packages (from scipy==1.13.1) (1.26.4)
# Downloading scipy-1.13.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (38.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 38.2/38.2 MB 18.1 MB/s eta 0:00:00
# Installing collected packages: scipy
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.16.1
#     Uninstalling scipy-1.16.1:
#       Successfully uninstalled scipy-1.16.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tsfresh 0.21.0 requires scipy>=1.14.0; python_version >= "3.10", but you have scipy 1.13.1 which is incompatible.
# Successfully installed scipy-1.13.1

# %%
import scipy
import statsmodels
print(scipy.__version__)
print(statsmodels.__version__)
# Out:
# 1.13.1
# 0.14.4

# %%
import pandas as pd
import numpy as np
import statsmodels.tsa.stattools as tsa
from matplotlib import pyplot as plt
from statsmodels.graphics.tsaplots import plot_pacf, plot_acf
import pmdarima as pm
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# Carga de datos y transformaciones necesarias

# %%
url='https://raw.githubusercontent.com/sebcalcagno/AnalisisSeriesTemporales/main/indices-precios-internacionales-productos-basicos-mensual.csv'
serie = pd.read_csv(url, index_col='indice_tiempo', parse_dates=[0])
serie = serie.asfreq('MS')

# %%
serie.head()
# Out:
#                     trigo        maiz  arroz     cebada  poroto_soja  \
# indice_tiempo
# 1980-01-01     175.634750  105.506813  395.0  66.584538   238.766037
# 1980-02-01     172.695236  114.167831  399.0  66.584538   241.361320
# 1980-03-01     163.509323  109.837318  415.0  69.897836   227.075780
# 1980-04-01     156.528030  108.262604  419.0  69.897836   218.210476
# 1980-05-01     161.304703  109.837318  433.0  68.241187   225.904457
#
#                harina_soja
# indice_tiempo
# 1980-01-01      201.756039
# 1980-02-01      198.261712
# 1980-03-01      186.103218
# 1980-04-01      181.197933
# 1980-05-01      187.392923

# %%
serie.tail()
# Out:
#                trigo   maiz  arroz  cebada  poroto_soja  harina_soja
# indice_tiempo
# 2017-02-01     147.3  162.9  368.5   136.2        380.9        371.4
# 2017-03-01     146.4  159.0  367.8   137.3        366.1        356.9
# 2017-04-01     138.4  156.4  374.5   138.8        347.9        342.6
# 2017-05-01     146.5  158.6  402.9   142.1        350.2        341.0
# 2017-06-01     157.2  158.0  444.7   140.8        339.7        330.4

# %% [markdown]
# **Haremos foco en Trigo, cebada y maíz:**

# %% [markdown]
# Visualizamos

# %%
serie.trigo.plot(figsize=(16,8));
serie.cebada.plot(figsize=(16,8));
serie.maiz.plot(figsize=(16,8));

# %%
# Agrupamos los datos por año y mes y calcula el promedio del precio del trigo para cada mes
precios_trigo_por_mes = serie['trigo'].groupby([serie.index.year, serie.index.month]).mean()


precios_trigo_por_mes = precios_trigo_por_mes.unstack(level=0)

# %%
intervalo_años = 4
precios_trigo_filtrados = precios_trigo_por_mes.iloc[:, ::intervalo_años]


plt.figure(figsize=(12, 6))
precios_trigo_filtrados.plot(marker='o', linestyle='-', ax=plt.gca())
plt.title('Evolución Mensual del Precio del Trigo (1980-2017) - Cada {} Años'.format(intervalo_años))
plt.xlabel('Mes')
plt.ylabel('Precio del Trigo')
plt.xticks(range(1, 13), ['Ene', 'Feb', 'Mar', 'Abr', 'May', 'Jun', 'Jul', 'Ago', 'Sep', 'Oct', 'Nov', 'Dic'])
plt.legend(title='Año')
plt.grid(True)
plt.show()

# %% [markdown]
# # SEPARO VARIABLES A TRABAJAR

# %% [markdown]
# # ANALISIS DE ESTACIONARIEDAD

# %% [markdown]
# **Que observamos a continuación?**
# Decrecimiento rápido o lento de las autocorrelaciones??
# Se observa algún patron periódico evidente??
# Las autocorrelaciones se encuentran cerca de cero??

# %% [markdown]
# Fuente = https://www.statsmodels.org/dev/generated/statsmodels.tsa.stattools.adfuller.html <br>
# Codigo= statsmodels.tsa.stattools.adfuller(serie.maiz, maxlag=None, regression='c', autolag='AIC', store=False, regresults=False)
#
# Variables para realizar los diferentes test de raices unitarias=
#
# <ol>
#
# <li>“c” : constant only (default)</li>
#
# <li>“ct” : constant and trend</li>
#
# <li>“ctt” : constant, and linear and quadratic trend</li>
#
# <li>“nc” : no constant, no trend</li>
#
# </ol>

# %% [markdown]
# Recordar: Si el valor p es igual o mayor que el nivel de significancia, no se rechaza la hipótesis nula, lo que sugiere que la serie es no estacionaria.

# %% [markdown]
# # Maiz

# %%
maiz_ts=serie.drop(['trigo','arroz','cebada','poroto_soja','harina_soja'], axis=1)

# %%
maiz_ts.head()
# Out:
#                      maiz
# indice_tiempo
# 1980-01-01     105.506813
# 1980-02-01     114.167831
# 1980-03-01     109.837318
# 1980-04-01     108.262604
# 1980-05-01     109.837318

# %%
print(pm.arima.ndiffs(maiz_ts))
# Out:
# 1

# %%
# Diferencio la serie
maiz_ts_diff=maiz_ts.copy()
maiz_ts_diff=maiz_ts_diff.diff(axis = 0, periods = 1)
maiz_ts_diff.drop(['1980-01-01'], inplace=True)

# %%
print(pm.arima.ndiffs(maiz_ts_diff))
# Out:
# 0

# %% [markdown]
# Primero analizamos serie original - MAIZ -

# %%
acf_plot = plot_acf(maiz_ts, lags=24,  color= 'blue')
acf_plot.set_size_inches(12,3)

# %% [markdown]
# Comentarios :
# - Si sabes que la serie tiene tendencia visual clara. ct.
#
# - Si la serie oscila alrededor de un nivel constante. c.
#
# - Si es un proceso estacionario puro centrado en cero. n [raro en datos reales). es decir, no tiene tendencia, ni nivel constante distinto de cero, y oscila aleatoriamente alrededor de cero.

# %%
# test DICKEY-FULLER
# No incluye término independiente ni lineal (“None”)
tsa.adfuller(serie.maiz, regression='n',autolag='AIC')
# Out:
# (-0.700627302548721,
#  0.41234587068932294,
#  16,
#  433,
#  {'1%': -2.5709228555275243,
#   '5%': -1.9416378864437647,
#   '10%': -1.6162207681657739},
#  3130.458609577689)

# %% [markdown]
# Este test estadistico indica si la serie tiene tendencia o no. Como el p-valor es mayor a 0.05, no podemos rechazar que tenga una raíz unitaria, lo que significa que la serie no es estacionaria.
# Tb  el estadístico ADF -0.7006 es menos negativo que cualquiera de los valores críticos-> Valor critico al 5%: -1.94

# %%
# Incluya término independiente pero no incluye término lineal (“Drift”)
tsa.adfuller(serie.maiz, regression='c',autolag='AIC')
# Out:
# (-2.1500183335277887,
#  0.2248830733867238,
#  16,
#  433,
#  {'1%': -3.445542818501549,
#   '5%': -2.868238133603207,
#   '10%': -2.5703378690483176},
#  3128.1145793319424)

# %%
# Incluya ambos términos (“Trend”)
tsa.adfuller(serie.maiz, regression='ct',autolag='AIC') #	AIC	BIC
# Out:
# (-2.932371299544158,
#  0.15197988628737646,
#  16,
#  433,
#  {'1%': -3.9798311295958153,
#   '5%': -3.420678245656216,
#   '10%': -3.133042572822471},
#  3126.1216090615862)

# %% [markdown]
# Ánalisis de la serie original diferenciada - MAIZ -

# %%
acf_plot = plot_acf(maiz_ts_diff, lags=24,  color= 'blue')
acf_plot.set_size_inches(12,3)

# %%
plot_pacf(maiz_ts_diff, lags=24,  color= 'blue');

# %%
# test DICKEY-FULLER
# No incluye término independiente ni lineal (“None”)
tsa.adfuller(maiz_ts_diff.maiz, regression='n',autolag='AIC')
# Out:
# (-4.9822245006963355,
#  1.1451336840197694e-06,
#  15,
#  433,
#  {'1%': -2.5709228555275243,
#   '5%': -1.9416378864437647,
#   '10%': -1.6162207681657739},
#  3122.0854272859406)

# %%
# Incluya término independiente pero no incluye término lineal (“Drift”)
tsa.adfuller(maiz_ts_diff.maiz, regression='c',autolag='AIC')
# Out:
# (-4.976639635671169,
#  2.4681049519257736e-05,
#  15,
#  433,
#  {'1%': -3.445542818501549,
#   '5%': -2.868238133603207,
#   '10%': -2.5703378690483176},
#  3124.066306519608)

# %%
# Incluya ambos términos (“Trend”)
tsa.adfuller(maiz_ts_diff.maiz, regression='ct',autolag='AIC')
# Out:
# (-4.974026169514543,
#  0.0002293639191854352,
#  15,
#  433,
#  {'1%': -3.9798311295958153,
#   '5%': -3.420678245656216,
#   '10%': -3.133042572822471},
#  3126.057083546732)

# %% [markdown]
# # Serie Trigo

# %% [markdown]
# Primero analizamos serie original - TRIGO -

# %%
trigo_ts=serie.drop(['cebada','arroz','maiz','poroto_soja','harina_soja'], axis=1)

# %%
print(pm.arima.ndiffs(trigo_ts))
# Out:
# 1

# %%
# Diferencio la serie
trigo_ts_diff=trigo_ts.copy()
trigo_ts_diff=trigo_ts_diff.diff(axis = 0, periods = 1)
trigo_ts_diff.drop(['1980-01-01'], inplace=True)

# %%
print(pm.arima.ndiffs(trigo_ts_diff))
# Out:
# 0

# %%
acf_plot = plot_acf(trigo_ts, lags=24,  color= 'blue')
acf_plot.set_size_inches(12,3)

# %%
# test DICKEY-FULLER
# No incluye término independiente ni lineal (“None”)
tsa.adfuller(trigo_ts.trigo, regression='n',autolag='AIC')
# Out:
# (-0.8576260517662297,
#  0.34641902329341384,
#  8,
#  441,
#  {'1%': -2.5708284909065666,
#   '5%': -1.9416260087080306,
#   '10%': -1.616231391782543},
#  3361.8032713653333)

# %%
# Incluya término independiente pero no incluye término lineal (“Drift”)
tsa.adfuller(trigo_ts.trigo, regression='c',autolag='AIC')
# Out:
# (-2.5743823514904056,
#  0.09840834221178346,
#  8,
#  441,
#  {'1%': -3.4452655826028318,
#   '5%': -2.868116205869215,
#   '10%': -2.570272878944473},
#  3357.9123884352484)

# %%
# Incluya ambos términos (“Trend”)
tsa.adfuller(trigo_ts.trigo, regression='ct',autolag='AIC')
# Out:
# (-2.9580081551660675,
#  0.14420184515063617,
#  8,
#  441,
#  {'1%': -3.979446309286507,
#   '5%': -3.420492546721216,
#   '10%': -3.132933481411034},
#  3357.784083010919)

# %% [markdown]
# Ánalisis de la serie original diferenciada - TRIGO -

# %%
acf_plot = plot_acf(trigo_ts_diff, lags=24,  color= 'blue')
acf_plot.set_size_inches(12,3)

# %%
# test DICKEY-FULLER
# No incluye término independiente ni lineal (“None”)
tsa.adfuller(trigo_ts_diff.trigo, regression='n',autolag='AIC')
# Out:
# (-8.354956120557224,
#  5.0735942453695186e-14,
#  7,
#  441,
#  {'1%': -2.5708284909065666,
#   '5%': -1.9416260087080306,
#   '10%': -1.616231391782543},
#  3353.6737875815734)

# %%
# Incluya término independiente pero no incluye término lineal (“Drift”)
tsa.adfuller(trigo_ts_diff.trigo, regression='c',autolag='AIC')
# Out:
# (-8.346129507545534,
#  3.082001598646072e-13,
#  7,
#  441,
#  {'1%': -3.4452655826028318,
#   '5%': -2.868116205869215,
#   '10%': -2.570272878944473},
#  3355.668322500598)

# %%
# Incluya ambos términos (“Trend”)
tsa.adfuller(trigo_ts_diff.trigo, regression='ct',autolag='AIC')
# Out:
# (-8.333420555413669,
#  1.2131363928091816e-11,
#  7,
#  441,
#  {'1%': -3.979446309286507,
#   '5%': -3.420492546721216,
#   '10%': -3.132933481411034},
#  3357.6679232346787)

# %% [markdown]
# # Serie cebada

# %%
cebada_ts=serie.drop(['trigo','arroz','maiz','poroto_soja','harina_soja'], axis=1)

# %%
cebada_ts.head()
# Out:
#                   cebada
# indice_tiempo
# 1980-01-01     66.584538
# 1980-02-01     66.584538
# 1980-03-01     69.897836
# 1980-04-01     69.897836
# 1980-05-01     68.241187

# %%
print(pm.arima.ndiffs(cebada_ts))
# Out:
# 1

# %%
# Diferencio la serie
cebada_ts_diff=cebada_ts.copy()
cebada_ts_diff=cebada_ts_diff.diff(axis = 0, periods = 1)
cebada_ts_diff.drop(['1980-01-01'], inplace=True)

# %%
print(pm.arima.ndiffs(cebada_ts_diff))
# Out:
# 0

# %% [markdown]
# Primero analizamos serie original - CEBADA -

# %%
acf_plot = plot_acf(cebada_ts, lags=24,  color= 'blue')
acf_plot.set_size_inches(12,3)

# %%
# test DICKEY-FULLER
# No incluye término independiente ni lineal (“None”)
tsa.adfuller(cebada_ts.cebada, regression='n',autolag='AIC')
# Out:
# (-0.5437923534785354,
#  0.47804145229843087,
#  1,
#  448,
#  {'1%': -2.5707486963887116,
#   '5%': -1.941615972306499,
#   '10%': -1.6162403831708814},
#  2918.2053844443963)

# %%
# Incluya término independiente pero no incluye término lineal (“Drift”)
tsa.adfuller(cebada_ts.cebada, regression='c',autolag='AIC')
# Out:
# (-2.1392501781073356,
#  0.22902747988534805,
#  1,
#  448,
#  {'1%': -3.4450311708077743,
#   '5%': -2.8680131035505023,
#   '10%': -2.570217924306441},
#  2916.169247664343)

# %%
# Incluya ambos términos (“Trend”)
tsa.adfuller(cebada_ts.cebada, regression='ct',autolag='AIC')
# Out:
# (-3.1481286096219185,
#  0.09524185611943131,
#  1,
#  448,
#  {'1%': -3.9791209459359305,
#   '5%': -3.420335526154187,
#   '10%': -3.1328412336343927},
#  2912.1236881710465)

# %% [markdown]
# Ánalisis de la serie original diferenciada - CEBADA -

# %%
acf_plot = plot_acf(cebada_ts_diff, lags=24,  color= 'blue')
acf_plot.set_size_inches(12,3)

# %%
# test DICKEY-FULLER
# No incluye término independiente ni lineal (“None”)
tsa.adfuller(cebada_ts_diff.cebada, regression='n',autolag='AIC')
# Out:
# (-16.366606421426578,
#  4.644271755843037e-28,
#  0,
#  448,
#  {'1%': -2.5707486963887116,
#   '5%': -1.941615972306499,
#   '10%': -1.6162403831708814},
#  2910.5404322989284)

# %%
# Incluya término independiente pero no incluye término lineal (“Drift”)
tsa.adfuller(cebada_ts_diff.cebada, regression='c',autolag='AIC')
# Out:
# (-16.354713763538978,
#  2.909398986151819e-29,
#  0,
#  448,
#  {'1%': -3.4450311708077743,
#   '5%': -2.8680131035505023,
#   '10%': -2.570217924306441},
#  2912.437592139488)

# %%
# Incluya ambos términos (“Trend”)
tsa.adfuller(cebada_ts_diff.cebada, regression='ct',autolag='AIC')
# Out:
# (-16.336571681333343,
#  0.0,
#  0,
#  448,
#  {'1%': -3.9791209459359305,
#   '5%': -3.420335526154187,
#   '10%': -3.1328412336343927},
#  2914.437468942544)

# %% [markdown]
# # Modelo VAR

# %% [markdown]
# Generamos el dataframe que vamos a utilizar

# %%
serieVAR=pd.concat([maiz_ts_diff, trigo_ts_diff, cebada_ts_diff], axis=1)

# %%
serieVAR.head()
# Out:
#                    maiz     trigo    cebada
# indice_tiempo
# 1980-02-01     8.661018 -2.939514  0.000000
# 1980-03-01    -4.330513 -9.185913  3.313298
# 1980-04-01    -1.574715 -6.981293  0.000000
# 1980-05-01     1.574715  4.776672 -1.656649
# 1980-06-01     3.543152 -3.674362 -3.313298

# %%
serieVAR.tail()
# Out:
#                maiz  trigo  cebada
# indice_tiempo
# 2017-02-01      2.9   10.2     4.1
# 2017-03-01     -3.9   -0.9     1.1
# 2017-04-01     -2.6   -8.0     1.5
# 2017-05-01      2.2    8.1     3.3
# 2017-06-01     -0.6   10.7    -1.3

# %%
# Separacion Train/Test

# Variable que guarda el porcentaje de train
split = .9

# Seleccion de train
train = serieVAR.iloc[:round(len(serieVAR)*split)]

# Seleccionamos de test
test = serieVAR.iloc[round(len(serieVAR)*split):]

# Corroboramos que los limites se hayan establecido segun lo planificado
print(train,"\n\n", test)
# Out:
#                     maiz      trigo     cebada
# indice_tiempo
# 1980-02-01      8.661018  -2.939514   0.000000
# 1980-03-01     -4.330513  -9.185913   3.313298
# 1980-04-01     -1.574715  -6.981293   0.000000
# 1980-05-01      1.574715   4.776672  -1.656649
# 1980-06-01      3.543152  -3.674362  -3.313298
# ...                  ...        ...        ...
# 2013-05-01     15.022317  13.026574  -0.999377
# 2013-06-01      1.764859 -10.265621  -0.835719
# 2013-07-01    -18.129510  -9.441619  -8.470014
# 2013-08-01    -44.038716   1.436343 -27.378026
# 2013-09-01    -27.483040   0.951279 -19.924691
#
# [404 rows x 3 columns]
#
#                      maiz      trigo     cebada
# indice_tiempo
# 2013-10-01     -5.680207  12.243653 -15.540935
# 2013-11-01     -2.590485 -12.890210  -2.940254
# 2013-12-01     -1.638616 -15.261064   0.012924
# 2014-01-01      1.218540 -15.621904   6.202309
# 2014-02-01     10.609191  14.547073   0.774812
# 2014-03-01     13.007051  32.810225  -1.172298
# 2014-04-01      0.028120  -2.105802   1.251631
# 2014-05-01     -5.436563  14.386060  10.480296
# 2014-06-01    -14.364711 -26.263848 -10.550880
# 2014-07-01    -20.333214 -23.054583 -21.651567
# 2014-08-01     -5.799782  -9.430318 -12.051999
# 2014-09-01    -13.366446 -17.944907  -2.426713
# 2014-10-01      0.247116   1.622997  -9.644305
# 2014-11-01     15.361498   3.168698   3.992878
# 2014-12-01      0.002757  17.021149   5.232977
# 2015-01-01     -3.964473 -22.362805   6.264033
# 2015-02-01     -1.009587  -8.893989  -3.206720
# 2015-03-01      0.530011   0.964873   4.000049
# 2015-04-01     -2.173560  -6.782666  -2.797529
# 2015-05-01     -5.756898  -2.743965  -2.245778
# 2015-06-01      0.423656   6.670646  -4.351381
# 2015-07-01     12.879669  -0.626313  10.205263
# 2015-08-01    -16.858884 -25.727128  -8.281589
# 2015-09-01      3.266625  -9.642827  -3.656472
# 2015-10-01      5.383092   1.561606   0.835083
# 2015-11-01     -5.360152  -7.646726   0.918592
# 2015-12-01     -2.079546   6.051717  -2.875591
# 2016-01-01     -2.950718   0.806755  -3.593580
# 2016-02-01     -1.300000  -5.300000   2.100000
# 2016-03-01     -0.600000   4.700000   1.000000
# 2016-04-01      5.300000  -0.600000   8.000000
# 2016-05-01      4.500000  -5.900000   6.000000
# 2016-06-01     11.000000  -0.900000  13.000000
# 2016-07-01    -18.100000 -23.000000  -7.900000
# 2016-08-01    -11.600000  -5.700000 -12.100000
# 2016-09-01     -1.800000  -4.700000  -3.000000
# 2016-10-01      4.200000  -0.700000   3.000000
# 2016-11-01     -1.300000   0.000000   3.400000
# 2016-12-01      1.400000   0.300000  -3.400000
# 2017-01-01      7.300000  14.300000   4.000000
# 2017-02-01      2.900000  10.200000   4.100000
# 2017-03-01     -3.900000  -0.900000   1.100000
# 2017-04-01     -2.600000  -8.000000   1.500000
# 2017-05-01      2.200000   8.100000   3.300000
# 2017-06-01     -0.600000  10.700000  -1.300000

# %%
train.head()
# Out:
#                    maiz     trigo    cebada
# indice_tiempo
# 1980-02-01     8.661018 -2.939514  0.000000
# 1980-03-01    -4.330513 -9.185913  3.313298
# 1980-04-01    -1.574715 -6.981293  0.000000
# 1980-05-01     1.574715  4.776672 -1.656649
# 1980-06-01     3.543152 -3.674362 -3.313298

# %%
test.head()
# Out:
#                     maiz      trigo     cebada
# indice_tiempo
# 2013-10-01     -5.680207  12.243653 -15.540935
# 2013-11-01     -2.590485 -12.890210  -2.940254
# 2013-12-01     -1.638616 -15.261064   0.012924
# 2014-01-01      1.218540 -15.621904   6.202309
# 2014-02-01     10.609191  14.547073   0.774812

# %% [markdown]
# # Criterio de Granger

# %% [markdown]
# La hipótesis nula supone que el pasado de una variable no proporciona información adicional para predecir la otra variable más allá de lo que ya se puede predecir utilizando solo su propio pasado.
# Es decir, es una funcion q nos permite ver si una serie ayuda a predecir otra, probando todos los pares posibles. Los valores bajos (p < 0.05) indican que hay evidencia estadística de que una variable X ayuda a anticipar Y.

# %%
from statsmodels.tsa.stattools import grangercausalitytests

# %%
# P-valores menores al nivel de significancia (0.05) implica que la hipotesis nula (X no causa Y) puede rechazarse.
# testgr: Es el tipo de prueba que se utilizará para evaluar la causalidad de Granger. Por defecto, se utiliza 'ssr_chi2test', que es una prueba basada en chi-cuadrado,

def grangers_causation_matrix(data, variables, maxlag, testgr='ssr_chi2test', verbose=False):


    df = pd.DataFrame(np.zeros((len(variables), len(variables))), columns=variables, index=variables)
    for c in df.columns:
        for r in df.index:
            test_result = grangercausalitytests(data[[r, c]], maxlag=maxlag, verbose=False)
            p_values = [(test_result[i+1][0][testgr][1],4) for i in range(maxlag)]
            if verbose: print(f'Y = {r}, X = {c}, P Values = {p_values}')
            min_p_value = np.min(p_values)
            df.loc[r, c] = min_p_value
    df.columns = [var + '_x' for var in variables]
    df.index = [var + '_y' for var in variables]
    return df

# se agrega '_x' al final de los nombres de las columnas para indicar que son las variables "causantes" y '_y' al final de los nombres de las filas para indicar que son las variables "afectadas".

# %% [markdown]
# - H0: La serie temporal X no causa grangerianamente la serie temporal Y.
# - H1: La serie temporal X causa grangerianamente la serie temporal Y.

# %%
testgr = 'ssr_chi2test'
grangers_causation_matrix(train, variables = train.columns, maxlag=20)
# Out:
#                 maiz_x       trigo_x      cebada_x
# maiz_y    1.000000e+00  2.981353e-10  1.020011e-04
# trigo_y   6.860754e-08  1.000000e+00  3.483198e-07
# cebada_y  1.075327e-11  1.216174e-16  1.000000e+00

# %% [markdown]
# Interpretación: Basándonos en el resultado de la prueba de causalidad de Granger, podemos afirmar que los valores pasados de Serie A (con un rezagos máximos de 20 períodos) proporcionan información estadísticamente significativa para predecir los valores futuros de Serie B. Esto sugiere una relación de causalidad grangeriana de Serie A hacia Serie B en este contexto específico.

# %%
from statsmodels.tsa.api import VAR

# %%
model = VAR(train)

# %% [markdown]
# -AIC (Akaike Information Criterion)
# -BIC (Bayesian Information Criterion)
# -FPE (Final Prediction Error)
# -HQIC (Hannan-Quinn Information Criterion)

# %% [markdown]
#  A continuación se utiliza el método select_order del modelo VAR (model) para seleccionar el orden adecuado del modelo VAR basado en criterios estadísticos. El parámetro maxlags se establece en 70, lo que significa que el código considerará modelos VAR con hasta 70 rezagos.

# %%
x = model.select_order(maxlags=70)
print(x.summary())
# Out:
#  VAR Order Selection (* highlights the minimums)
# ==================================================
#        AIC         BIC         FPE         HQIC
# --------------------------------------------------
# 0        13.27       13.31   5.808e+05       13.29
# 1        13.09      13.23*   4.838e+05      13.14*
# 2        13.08       13.32   4.809e+05       13.18
# 3        13.05       13.40   4.670e+05       13.19
# 4        13.09       13.53   4.827e+05       13.26
# 5        12.98       13.53   4.356e+05       13.20
# 6        12.98       13.63   4.345e+05       13.24
# 7        12.95       13.70   4.198e+05       13.25
# 8        12.92       13.78   4.106e+05       13.27
# 9        12.88       13.84   3.944e+05       13.27
# 10       12.88       13.94   3.944e+05       13.31
# 11       12.92       14.08   4.087e+05       13.38
# 12       12.95       14.21   4.207e+05       13.45
# 13       12.90       14.27   4.020e+05       13.45
# 14       12.89       14.36   3.975e+05       13.48
# 15       12.88       14.45   3.942e+05       13.51
# 16       12.83       14.51   3.751e+05       13.50
# 17       12.84       14.62   3.786e+05       13.55
# 18      12.76*       14.65  3.527e+05*       13.51
# 19       12.78       14.77   3.603e+05       13.58
# - Hay 3 ecuaciones: una para cada variable (maíz, trigo, cebada).
# - Lag order: 18	Usás un modelo VAR(18)
# - Nobs: 386	Se usaron 386 observaciones.
#
# - Ecuacion del maiz :
# Ej L5.maiz    -0.179247   (t=-2.662, p=0.008)
#
# Aca :
# maiz rezagado 5 periodos influye negativamente en el maíz actual.
# p=0.008 quiere decir que es estadisticamente significativo.
#
#
# Es decir, los precios pasados del maíz y trigo ayudan a predecir el maíz actual.
#
# - Ej con un modelo VAR(1) para tres precios agrícolas. Encontramos que el precio del maiz depende de su valor anterior y del trigo. El trigo depende solo de sí mismo. La cebada esta influenciada significativamente por el maiz y el trigo. Esto sugiere relaciones dinamicas cruzadas en el corto plazo.

# %% [markdown]
# Prediccion

# %%
# Funcion que recibe listas con las predicciones e intervalos de confianza de las 3 series y devuelve un
# dataframe para la serie indicada por la variable indice
def serializar(predicciones_, test_, indice, futuro_, intervalos=True):

    serie = {
        "FECHA": test_.index[:futuro_],
        "serie"+str(indice): predicciones_[0][:,indice-1].tolist(),
        "serie"+str(indice)+"_inf": predicciones_[1][:,indice-1].tolist(),
        "serie"+str(indice)+"_sup": predicciones_[2][:,indice-1].tolist()}
    serie = pd.DataFrame(serie, columns=["FECHA", "serie"+str(indice),
                                         "serie"+str(indice)+"_inf", "serie"+str(indice)+"_sup"])
    serie.set_index("FECHA", inplace=True)
    if (intervalos==False):
        serie.loc[serie["serie"+str(indice)+"_inf"] < 0, "serie"+str(indice)+"_inf"] = 0
        serie.loc[serie["serie"+str(indice)+"_sup"] < 0, "serie"+str(indice)+"_sup"] = 0
    return serie

# %%
def graficar_pred(serie_test, serie_pred, titulo="Valores Originales vs Predicciones",
                  xlabel="Fecha", ylabel="Valor", intervalos=True):
    # serie_test:
    # serie_pred:

    fig_x = plt.figure(figsize=(12,3), dpi=100)
    axes_x = fig_x.add_axes([0.0, 0.0, 1, 1])

    # Graficamos los datos tests y las predicciones
    serie_test.plot(label="Serie Original de Test")
    serie_pred.iloc[:,0].plot(label="Predicciones")
    if (intervalos==True):
        serie_pred.iloc[:,2].plot(label="Intervalo de Confianza Superior")
        serie_pred.iloc[:,1].plot(label="Intervalo de Confianza Inferior")

    axes_x.set_xlabel(xlabel)
    axes_x.set_ylabel(ylabel)
    axes_x.set_title(titulo)
    axes_x.legend(loc=0)
    axes_x.grid(True, color='0.5', dashes=(5,2,1,2))


'''
sirve para visualizar las predicciones de una serie temporal junto con los valores reales y los intervalos de confianza.
'''
# Out:
# '\nsirve para visualizar las predicciones de una serie temporal junto con los valores reales y los intervalos de confianza.\n'

# %%
# Con la variable futuro se indican cuantas unidades en tiempo
# hacia adelante se quieren predecir
futuro = 45
lag_orden = 18

predicciones = model_fitted.forecast_interval(train.values[-lag_orden:], steps=futuro)

df = list()
for i in [1, 2, 3]:
    df.append(serializar(predicciones, test, i, futuro))

for i, serie in enumerate(serieVAR):
    graficar_pred(test[serie][:futuro], df[i], titulo=serie)

# %%
def evaluar_metricas(serie_test, serie_pred):
    print(f'MSE: {mean_squared_error(serie_test, serie_pred)}')
    print(f'MAE: {mean_absolute_error(serie_test, serie_pred)}')
    print(f'RMSE: {np.sqrt(mean_squared_error(serie_test, serie_pred))}')
    print(f'MAPE: {round(np.mean(abs((serie_test-serie_pred)/serie_test)),4)}')

# %%
def test_residuos(residuos):


    # Test de Jarque Bera
    # H0: los datos estan distribuidos normalmente
    # Ha: los datos no estan distribuidos normalmente
    # Si p < 0.05 se rechaza la hipotesis nula
    jarquebera = jarque_bera(residuos)
    print('Jarque-Bera')
    print(f'p-valor: {jarquebera[1]}\n')

    # Test de Shapiro Wilks
    # H0: los datos estan distribuidos normalmente
    # Ha: los datos no estan distribuidos normalmente
    # Si p < 0.05 se rechaza la hipotesis nula
    shapir = shapiro(residuos)
    print('Shapiro')
    print(f'p-valor: {shapir[1]}\n')


    '''
Estos dos tests sirven para saber si los errores del modelo se distribuyen como una campana normal.
Eso es importante porque muchos modelos suponen que los residuos son normales.
Si alguno de estos tests da un p-valor menor a 0.05, significa que los errores no cumplen esa condicion,
y eso puede afectar la calidad del modelo o de los intervalos de confianza
    '''

# %%
def evaluar_residuos(residuos):
    residuos.plot(title='Residuos', figsize=(12, 3))
    plt.axhline(0, linestyle='--', color='k')
    plt.show()
    fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(12, 3))
    ax[0].set_title('Residuos KDE')
    ax[1].set_title('Q-Q Plot')
    residuos.plot(kind='kde', ax=ax[0])
    probplot(residuos, dist='norm', plot=ax[1])
    plt.show()
    acf = plot_acf(residuos)
    acf.set_size_inches(12,3)
    plt.show()
    print('Descriptivo Residuos\n')
    print(f'{residuos.describe()}\n\n')
    print('Test sobre los Residuos\n')
    test_residuos(residuos)



#Esta funcion sirve para analizar si los errores del modelo estan bien comportados.
#Un buen modelo deberia tener residuos centrados en cero, sin autocorrelacion y distribuidos normalmente.
#Si no se cumple, el modelo podría estar mal especificado o faltar alguna variable explicativa

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error
from scipy.stats import jarque_bera, shapiro, boxcox, probplot
from statsmodels.graphics.tsaplots import plot_pacf, plot_acf
from statsmodels.stats.diagnostic import acorr_ljungbox, acorr_breusch_godfrey

# %%
futuro
# Out:
# 45

# %%
test.cebada[:futuro]
# Out:
# indice_tiempo
# 2013-10-01   -15.540935
# 2013-11-01    -2.940254
# 2013-12-01     0.012924
# 2014-01-01     6.202309
# 2014-02-01     0.774812
# 2014-03-01    -1.172298
# 2014-04-01     1.251631
# 2014-05-01    10.480296
# 2014-06-01   -10.550880
# 2014-07-01   -21.651567
# 2014-08-01   -12.051999
# 2014-09-01    -2.426713
# 2014-10-01    -9.644305
# 2014-11-01     3.992878
# 2014-12-01     5.232977
# 2015-01-01     6.264033
# 2015-02-01    -3.206720
# 2015-03-01     4.000049
# 2015-04-01    -2.797529
# 2015-05-01    -2.245778
# 2015-06-01    -4.351381
# 2015-07-01    10.205263
# 2015-08-01    -8.281589
# 2015-09-01    -3.656472
# 2015-10-01     0.835083
# 2015-11-01     0.918592
# 2015-12-01    -2.875591
# 2016-01-01    -3.593580
# 2016-02-01     2.100000
print(f"Evaluacion de residuos de Serie ")
evaluar_residuos(test[serie][:futuro]-df[0].iloc[:,0])
# Out:
# maiz
# -----------------------------
# MSE: 77.02526499337338
# MAE: 6.750630914304971
# RMSE: 8.776403875926254
# MAPE: 62.4744
# Evaluacion de residuos de Serie
# Descriptivo Residuos
#
# count    45.000000
# mean     -1.578524
# std       8.547923
# min     -20.604221
# 25%      -8.033848
# 50%      -1.276123
# 75%       4.476611
# max      15.466142
# dtype: float64
#
#
# Test sobre los Residuos
#
# Jarque-Bera
# p-valor: 0.7471583983911969
#
# Shapiro
# p-valor: 0.8929738359117009

# %% [markdown]
# Tests de normalidad
# Ambos p-valores > 0.05, por lo tanto NO se rechaza la hipotesis nula de normalidad.
# los residuos pueden considerarse normales lo cual es deseable.
#
# MAE = 6.75 Es decir, en promedio, el modelo se equivoca unos 6 puntos respecto al valor real del maiz.

# %% [markdown]
# Ambas pruebas indican que no hay suficiente evidencia para rechazar la hipótesis nula de que los residuos del modelo siguen una distribución normal. Esto es una señal positiva para la calidad del modelo, ya que los modelos VAR (y muchos otros modelos estadísticos) asumen que los residuos son aproximadamente normales para que las inferencias y predicciones sean válidas.

# %%
print("trigo")
print("-----------------------------")
evaluar_metricas(test.trigo[:futuro], df[1].iloc[:,0])
print(f"Evaluacion de residuos de Serie ")
evaluar_residuos(test[serie][:futuro]-df[1].iloc[:,0])
# Out:
# trigo
# -----------------------------
# MSE: 181.71803213622388
# MAE: 9.788927131869405
# RMSE: 13.480283088133715
# MAPE: inf
# Evaluacion de residuos de Serie
# Descriptivo Residuos
#
# count    45.000000
# mean     -0.348845
# std       9.884735
# min     -23.434578
# 25%      -7.507468
# 50%       0.857468
# 75%       3.908692
# max      40.487030
# dtype: float64
#
#
# Test sobre los Residuos
#
# Jarque-Bera
# p-valor: 3.8328514821907727e-13
#
# Shapiro
# p-valor: 0.00043373781084178983

# %%
print("cebada")
print("-----------------------------")

evaluar_metricas(test.cebada[:futuro], df[2].iloc[:,0])
print(f"Evaluacion de residuos de Serie ")
evaluar_residuos(test[serie][:futuro]-df[2].iloc[:,0])
# Out:
# cebada
# -----------------------------
# MSE: 47.36727411731684
# MAE: 5.519279225398779
# RMSE: 6.882388692693609
# MAPE: 15.3079
# Evaluacion de residuos de Serie
# Descriptivo Residuos
#
# count    45.000000
# mean     -1.337186
# std       6.827525
# min     -19.376180
# 25%      -5.481023
# 50%      -1.576136
# 75%       3.527187
# max      14.012558
# dtype: float64
#
#
# Test sobre los Residuos
#
# Jarque-Bera
# p-valor: 0.7173448838908636
#
# Shapiro
# p-valor: 0.6919818211584222

# %% [markdown]
# **Analizamos los Impulsos respuesta:**
#
# Cómo las variables en el modelo responden a un shock o perturbación en una de las variables.

# %%
model_fitted.irf(50).plot();

# %% [markdown]
# Ej : Grafico del centro arriba (trigo -> maiz): como se ve afectado el maiz por un shock en el trigo. Un shock en trigo provoca una respuesta positiva inicial en maiz pero se estabiliza despues de 10 periodos.
